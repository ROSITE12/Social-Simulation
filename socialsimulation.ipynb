# %% [markdown]
# # Introducción a la simulación social
# ---
# - Alumna: Rosa Humaní Pucho
# - Código: 20200422

# %% [markdown]
# ## Ejercicio 1: visualización de puntajes tras varias rondas

# %%
# Estrategias
strategies=['Rock','Paper','Scissors']

# %%
# reglas
payoff={('Rock','Paper'):(0,1),
        ('Paper','Rock'):(1,0),
        ('Rock','Scissors'):(1,0),
        ('Scissors','Rock'):(0,1),
        ('Paper','Scissors'):(0,1),
        ('Scissors','Paper'):(1,0),
        ('Rock','Rock'):(0,0),
        ('Paper','Paper'):(0,0),
        ('Scissors','Scissors'):(0,0)}

# %%
# nonmbre de los jugadores
names=['Jim','Jane','Peter','Zoe']

# %%
from random import choice

# Estrategia de juego escogida al azar
choice(strategies);

# %%
# setting up players
society=[{'name':n,'score':0,'strategy':None} for n in names]

# %%
# cada jugador tiene un diccionario
society
# Out:
# [{'name': 'Jim', 'score': 0, 'strategy': None},
#  {'name': 'Jane', 'score': 0, 'strategy': None},
#  {'name': 'Peter', 'score': 0, 'strategy': None},
#  {'name': 'Zoe', 'score': 0, 'strategy': None}]

# %%
import itertools

# cada par es una dupla de diccionarios
for pair in itertools.combinations(society,2):
    print(pair)
# Out:
# ({'name': 'Jim', 'score': 0, 'strategy': None}, {'name': 'Jane', 'score': 0, 'strategy': None})
# ({'name': 'Jim', 'score': 0, 'strategy': None}, {'name': 'Peter', 'score': 0, 'strategy': None})
# ({'name': 'Jim', 'score': 0, 'strategy': None}, {'name': 'Zoe', 'score': 0, 'strategy': None})
# ({'name': 'Jane', 'score': 0, 'strategy': None}, {'name': 'Peter', 'score': 0, 'strategy': None})
# ({'name': 'Jane', 'score': 0, 'strategy': None}, {'name': 'Zoe', 'score': 0, 'strategy': None})
# ({'name': 'Peter', 'score': 0, 'strategy': None}, {'name': 'Zoe', 'score': 0, 'strategy': None})

# %%
import itertools

for player1,player2 in itertools.combinations(society,2):
    print(player1,player2)
# Out:
# {'name': 'Jim', 'score': 0, 'strategy': None} {'name': 'Jane', 'score': 0, 'strategy': None}
# {'name': 'Jim', 'score': 0, 'strategy': None} {'name': 'Peter', 'score': 0, 'strategy': None}
# {'name': 'Jim', 'score': 0, 'strategy': None} {'name': 'Zoe', 'score': 0, 'strategy': None}
# {'name': 'Jane', 'score': 0, 'strategy': None} {'name': 'Peter', 'score': 0, 'strategy': None}
# {'name': 'Jane', 'score': 0, 'strategy': None} {'name': 'Zoe', 'score': 0, 'strategy': None}
# {'name': 'Peter', 'score': 0, 'strategy': None} {'name': 'Zoe', 'score': 0, 'strategy': None}

# %%
# restablecer
society=[{'name':n,'score':0,'strategy':None} for n in names]

# varias rondas
for aRound in range(100):

    # en cada ronda:
    for player1,player2 in itertools.combinations(society,2):
        # escogr la estrategia
        player1['strategy']=choice(strategies)

        player2['strategy']=choice(strategies)

        # resultado de cada estartegia escogida
        result=payoff[player1['strategy'],player2['strategy']]

        # incluir puntajes
        player1['score']+=result[0]
        player2['score']+=result[1]

# IMPRIMIR LOS RESULTADOS DE CADA PAR EN CADA RONDA :)
        print(f"{player1['name']} ({player1['strategy']}) vs {player2['name']} ({player2['strategy']}) -> "
              f"Scores: {player1['name']} {player1['score']}, {player2['name']} {player2['score']}")

    print("\nCurrent standings:")
    for player in society:
        print(f"{player['name']} -> Score: {player['score']}")
    print("=" * 50)  # Separador entre rondas
# Out:
# Jim (Rock) vs Jane (Scissors) -> Scores: Jim 1, Jane 0
# Jim (Paper) vs Peter (Scissors) -> Scores: Jim 1, Peter 1
# Jim (Paper) vs Zoe (Rock) -> Scores: Jim 2, Zoe 0
# Jane (Paper) vs Peter (Scissors) -> Scores: Jane 0, Peter 2
# Jane (Paper) vs Zoe (Scissors) -> Scores: Jane 0, Zoe 1
# Peter (Scissors) vs Zoe (Rock) -> Scores: Peter 2, Zoe 2
#
# Current standings:
# Jim -> Score: 2
# Jane -> Score: 0
# Peter -> Score: 2
# Zoe -> Score: 2
# ==================================================
# Jim (Rock) vs Jane (Scissors) -> Scores: Jim 3, Jane 0
# Jim (Scissors) vs Peter (Scissors) -> Scores: Jim 3, Peter 2
# Jim (Paper) vs Zoe (Scissors) -> Scores: Jim 3, Zoe 3
# Jane (Rock) vs Peter (Scissors) -> Scores: Jane 1, Peter 2
# Jane (Scissors) vs Zoe (Scissors) -> Scores: Jane 1, Zoe 3
# Peter (Scissors) vs Zoe (Paper) -> Scores: Peter 3, Zoe 3
#
# Current standings:
# Jim -> Score: 3
# Jane -> Score: 1
# Peter -> Score: 3
# Zoe -> Score: 3
# ==================================================
# Jim (Paper) vs Jane (Rock) -> Scores: Jim 4, Jane 1
# Jim (Scissors) vs Peter (Rock) -> Scores: Jim 4, Peter 4
# Jim (Paper) vs Zoe (Paper) -> Scores: Jim 4, Zoe 3
# Jane (Rock) vs Peter (Scissors) -> Scores: Jane 2, Peter 4
# Jane (Scissors) vs Zoe (Paper) -> Scores: Jane 3, Zoe 3
# Peter (Paper) vs Zoe (Rock) -> Scores: Peter 5, Zoe 3
#
# Current standings:
# Jim -> Score: 4
# Jane -> Score: 3
# Peter -> Score: 5
# Zoe -> Score: 3
# ==================================================
# Jim (Paper) vs Jane (Scissors) -> Scores: Jim 4, Jane 4
# Jim (Scissors) vs Peter (Rock) -> Scores: Jim 4, Peter 6
# Jim (Rock) vs Zoe (Paper) -> Scores: Jim 4, Zoe 4
# Jane (Scissors) vs Peter (Rock) -> Scores: Jane 4, Peter 7
# Jane (Scissors) vs Zoe (Scissors) -> Scores: Jane 4, Zoe 4
# Peter (Paper) vs Zoe (Rock) -> Scores: Peter 8, Zoe 4
#
# Current standings:
# Jim -> Score: 4
# Jane -> Score: 4
# Peter -> Score: 8
# Zoe -> Score: 4
# ==================================================
# Jim (Rock) vs Jane (Scissors) -> Scores: Jim 5, Jane 4
# Jim (Rock) vs Peter (Paper) -> Scores: Jim 5, Peter 9
# Jim (Scissors) vs Zoe (Scissors) -> Scores: Jim 5, Zoe 4
# Jane (Paper) vs Peter (Scissors) -> Scores: Jane 4, Peter 10
# Jane (Scissors) vs Zoe (Paper) -> Scores: Jane 5, Zoe 4
# Peter (Rock) vs Zoe (Paper) -> Scores: Peter 10, Zoe 5
#
# Current standings:
# Jim -> Score: 5
# Jane -> Score: 5
# Peter -> Score: 10
# Zoe -> Score: 5
# ==================================================
# Jim (Rock) vs Jane (Rock) -> Scores: Jim 5, Jane 5
# Jim (Rock) vs Peter (Rock) -> Scores: Jim 5, Peter 10
# Jim (Rock) vs Zoe (Rock) -> Scores: Jim 5, Zoe 5
# Jane (Paper) vs Peter (Rock) -> Scores: Jane 6, Peter 10
# Jane (Scissors) vs Zoe (Scissors) -> Scores: Jane 6, Zoe 5
# Peter (Paper) vs Zoe (Paper) -> Scores: Peter 10, Zoe 5
#
# Current standings:
# Jim -> Score: 5
# Jane -> Score: 6
# Peter -> Score: 10
# Zoe -> Score: 5
# ==================================================
# Jim (Paper) vs Jane (Paper) -> Scores: Jim 5, Jane 6
# Jim (Scissors) vs Peter (Rock) -> Scores: Jim 5, Peter 11
# Jim (Paper) vs Zoe (Scissors) -> Scores: Jim 5, Zoe 6
# Jane (Paper) vs Peter (Paper) -> Scores: Jane 6, Peter 11
# Jane (Rock) vs Zoe (Scissors) -> Scores: Jane 7, Zoe 6
# Peter (Paper) vs Zoe (Rock) -> Scores: Peter 12, Zoe 6
#
# Current standings:
# Jim -> Score: 5
# Jane -> Score: 7
# Peter -> Score: 12
# Zoe -> Score: 6
# ==================================================
# Jim (Rock) vs Jane (Rock) -> Scores: Jim 5, Jane 7
# Jim (Rock) vs Peter (Paper) -> Scores: Jim 5, Peter 13
# Jim (Paper) vs Zoe (Paper) -> Scores: Jim 5, Zoe 6
# Jane (Scissors) vs Peter (Rock) -> Scores: Jane 7, Peter 14
# Jane (Scissors) vs Zoe (Rock) -> Scores: Jane 7, Zoe 7
# Peter (Rock) vs Zoe (Scissors) -> Scores: Peter 15, Zoe 7
#
# Current standings:
# Jim -> Score: 5
# Jane -> Score: 7
# Peter -> Score: 15
# Zoe -> Score: 7
# ==================================================
# Jim (Rock) vs Jane (Rock) -> Scores: Jim 5, Jane 7
# Jim (Rock) vs Peter (Scissors) -> Scores: Jim 6, Peter 15
# Jim (Rock) vs Zoe (Paper) -> Scores: Jim 6, Zoe 8
# Jane (Paper) vs Peter (Paper) -> Scores: Jane 7, Peter 15
# Jane (Rock) vs Zoe (Paper) -> Scores: Jane 7, Zoe 9
# Peter (Paper) vs Zoe (Rock) -> Scores: Peter 16, Zoe 9
#
# Current standings:
# Jim -> Score: 6
# Jane -> Score: 7
# Peter -> Score: 16
# Zoe -> Score: 9
# ==================================================
# Jim (Scissors) vs Jane (Paper) -> Scores: Jim 7, Jane 7
# Jim (Rock) vs Peter (Rock) -> Scores: Jim 7, Peter 16
# Jim (Scissors) vs Zoe (Paper) -> Scores: Jim 8, Zoe 9
# Jane (Rock) vs Peter (Paper) -> Scores: Jane 7, Peter 17
# Jane (Paper) vs Zoe (Scissors) -> Scores: Jane 7, Zoe 10
# Peter (Rock) vs Zoe (Scissors) -> Scores: Peter 18, Zoe 10
#
# Current standings:
# Jim -> Score: 8
# Jane -> Score: 7
# Peter -> Score: 18
# Zoe -> Score: 10
# ==================================================
# Jim (Rock) vs Jane (Rock) -> Scores: Jim 8, Jane 7
# Jim (Scissors) vs Peter (Rock) -> Scores: Jim 8, Peter 19
# Jim (Scissors) vs Zoe (Scissors) -> Scores: Jim 8, Zoe 10
# Jane (Rock) vs Peter (Rock) -> Scores: Jane 7, Peter 19
# Jane (Scissors) vs Zoe (Rock) -> Scores: Jane 7, Zoe 11
# Peter (Paper) vs Zoe (Rock) -> Scores: Peter 20, Zoe 11
#
# Current standings:
# Jim -> Score: 8
# Jane -> Score: 7
# Peter -> Score: 20
# Zoe -> Score: 11
# ==================================================
# Jim (Scissors) vs Jane (Scissors) -> Scores: Jim 8, Jane 7
# Jim (Rock) vs Peter (Scissors) -> Scores: Jim 9, Peter 20
# Jim (Rock) vs Zoe (Paper) -> Scores: Jim 9, Zoe 12
# Jane (Scissors) vs Peter (Paper) -> Scores: Jane 8, Peter 20
# Jane (Rock) vs Zoe (Rock) -> Scores: Jane 8, Zoe 12
# Peter (Paper) vs Zoe (Scissors) -> Scores: Peter 20, Zoe 13
#
# Current standings:
# Jim -> Score: 9
# Jane -> Score: 8
# Peter -> Score: 20
# Zoe -> Score: 13
# ==================================================
# Jim (Paper) vs Jane (Rock) -> Scores: Jim 10, Jane 8
# Jim (Scissors) vs Peter (Paper) -> Scores: Jim 11, Peter 20
# Jim (Scissors) vs Zoe (Scissors) -> Scores: Jim 11, Zoe 13
# Jane (Paper) vs Peter (Rock) -> Scores: Jane 9, Peter 20
# Jane (Scissors) vs Zoe (Scissors) -> Scores: Jane 9, Zoe 13
# Peter (Rock) vs Zoe (Scissors) -> Scores: Peter 21, Zoe 13
#
# Current standings:
# Jim -> Score: 11
# Jane -> Score: 9
# Peter -> Score: 21
# Zoe -> Score: 13
# ==================================================
# Jim (Rock) vs Jane (Rock) -> Scores: Jim 11, Jane 9
# Jim (Paper) vs Peter (Scissors) -> Scores: Jim 11, Peter 22
# Jim (Paper) vs Zoe (Scissors) -> Scores: Jim 11, Zoe 14
# Jane (Paper) vs Peter (Scissors) -> Scores: Jane 9, Peter 23
# Jane (Paper) vs Zoe (Rock) -> Scores: Jane 10, Zoe 14
# Peter (Rock) vs Zoe (Scissors) -> Scores: Peter 24, Zoe 14
#
# Current standings:
# Jim -> Score: 11
# Jane -> Score: 10
# Peter -> Score: 24
# Zoe -> Score: 14
# ==================================================
# Jim (Rock) vs Jane (Rock) -> Scores: Jim 11, Jane 10
# Jim (Scissors) vs Peter (Paper) -> Scores: Jim 12, Peter 24
# Jim (Scissors) vs Zoe (Scissors) -> Scores: Jim 12, Zoe 14
# Jane (Rock) vs Peter (Paper) -> Scores: Jane 10, Peter 25
# Jane (Scissors) vs Zoe (Scissors) -> Scores: Jane 10, Zoe 14
# Peter (Rock) vs Zoe (Scissors) -> Scores: Peter 26, Zoe 14
#
# Current standings:
# Jim -> Score: 12
# Jane -> Score: 10
# Peter -> Score: 26
# Zoe -> Score: 14
# ==================================================
# Jim (Rock) vs Jane (Scissors) -> Scores: Jim 13, Jane 10
# Jim (Scissors) vs Peter (Rock) -> Scores: Jim 13, Peter 27
# Jim (Scissors) vs Zoe (Paper) -> Scores: Jim 14, Zoe 14
# Jane (Paper) vs Peter (Rock) -> Scores: Jane 11, Peter 27
# Jane (Paper) vs Zoe (Scissors) -> Scores: Jane 11, Zoe 15
# Peter (Paper) vs Zoe (Paper) -> Scores: Peter 27, Zoe 15
#
# Current standings:
# Jim -> Score: 14
# Jane -> Score: 11
# Peter -> Score: 27
# Zoe -> Score: 15
# ==================================================
# Jim (Rock) vs Jane (Scissors) -> Scores: Jim 15, Jane 11
# Jim (Rock) vs Peter (Scissors) -> Scores: Jim 16, Peter 27
# Jim (Scissors) vs Zoe (Rock) -> Scores: Jim 16, Zoe 16
# Jane (Rock) vs Peter (Paper) -> Scores: Jane 11, Peter 28
# Jane (Paper) vs Zoe (Paper) -> Scores: Jane 11, Zoe 16
# Peter (Paper) vs Zoe (Scissors) -> Scores: Peter 28, Zoe 17
#
# Current standings:
# Jim -> Score: 16
# Jane -> Score: 11
# Peter -> Score: 28
# Zoe -> Score: 17
# ==================================================
# Jim (Scissors) vs Jane (Scissors) -> Scores: Jim 16, Jane 11
# Jim (Rock) vs Peter (Paper) -> Scores: Jim 16, Peter 29
# Jim (Scissors) vs Zoe (Rock) -> Scores: Jim 16, Zoe 18
# Jane (Rock) vs Peter (Scissors) -> Scores: Jane 12, Peter 29
# Jane (Rock) vs Zoe (Paper) -> Scores: Jane 12, Zoe 19
# Peter (Scissors) vs Zoe (Rock) -> Scores: Peter 29, Zoe 20
#
# Current standings:
# Jim -> Score: 16
# Jane -> Score: 12
# Peter -> Score: 29
# Zoe -> Score: 20
# ==================================================
# Jim (Paper) vs Jane (Paper) -> Scores: Jim 16, Jane 12
# Jim (Rock) vs Peter (Rock) -> Scores: Jim 16, Peter 29
# Jim (Rock) vs Zoe (Scissors) -> Scores: Jim 17, Zoe 20
# Jane (Scissors) vs Peter (Scissors) -> Scores: Jane 12, Peter 29
# Jane (Scissors) vs Zoe (Paper) -> Scores: Jane 13, Zoe 20
# Peter (Scissors) vs Zoe (Paper) -> Scores: Peter 30, Zoe 20
#
# Current standings:
# Jim -> Score: 17
# Jane -> Score: 13
# Peter -> Score: 30
# Zoe -> Score: 20
# ==================================================
# Jim (Rock) vs Jane (Rock) -> Scores: Jim 17, Jane 13
# Jim (Paper) vs Peter (Rock) -> Scores: Jim 18, Peter 30
# Jim (Paper) vs Zoe (Scissors) -> Scores: Jim 18, Zoe 21
# Jane (Paper) vs Peter (Rock) -> Scores: Jane 14, Peter 30
# Jane (Paper) vs Zoe (Scissors) -> Scores: Jane 14, Zoe 22
# Peter (Rock) vs Zoe (Paper) -> Scores: Peter 30, Zoe 23
#
# Current standings:
# Jim -> Score: 18
# Jane -> Score: 14
# Peter -> Score: 30
# Zoe -> Score: 23
# ==================================================
# Jim (Paper) vs Jane (Rock) -> Scores: Jim 19, Jane 14
# Jim (Rock) vs Peter (Paper) -> Scores: Jim 19, Peter 31
# Jim (Rock) vs Zoe (Rock) -> Scores: Jim 19, Zoe 23
# Jane (Rock) vs Peter (Rock) -> Scores: Jane 14, Peter 31
# Jane (Scissors) vs Zoe (Paper) -> Scores: Jane 15, Zoe 23
# Peter (Paper) vs Zoe (Rock) -> Scores: Peter 32, Zoe 23
#
# Current standings:
# Jim -> Score: 19
# Jane -> Score: 15
# Peter -> Score: 32
# Zoe -> Score: 23
# ==================================================
# Jim (Rock) vs Jane (Scissors) -> Scores: Jim 20, Jane 15
# Jim (Scissors) vs Peter (Rock) -> Scores: Jim 20, Peter 33
# Jim (Scissors) vs Zoe (Scissors) -> Scores: Jim 20, Zoe 23
# Jane (Rock) vs Peter (Scissors) -> Scores: Jane 16, Peter 33
# Jane (Scissors) vs Zoe (Rock) -> Scores: Jane 16, Zoe 24
# Peter (Rock) vs Zoe (Rock) -> Scores: Peter 33, Zoe 24
#
# Current standings:
# Jim -> Score: 20
# Jane -> Score: 16
# Peter -> Score: 33
# Zoe -> Score: 24
# ==================================================
# Jim (Rock) vs Jane (Paper) -> Scores: Jim 20, Jane 17
# Jim (Scissors) vs Peter (Scissors) -> Scores: Jim 20, Peter 33
# Jim (Scissors) vs Zoe (Rock) -> Scores: Jim 20, Zoe 25
# Jane (Scissors) vs Peter (Scissors) -> Scores: Jane 17, Peter 33
# Jane (Rock) vs Zoe (Scissors) -> Scores: Jane 18, Zoe 25
# Peter (Paper) vs Zoe (Rock) -> Scores: Peter 34, Zoe 25
#
# Current standings:
# Jim -> Score: 20
# Jane -> Score: 18
# Peter -> Score: 34
# Zoe -> Score: 25
# ==================================================
# Jim (Scissors) vs Jane (Rock) -> Scores: Jim 20, Jane 19
# Jim (Rock) vs Peter (Rock) -> Scores: Jim 20, Peter 34
# Jim (Rock) vs Zoe (Rock) -> Scores: Jim 20, Zoe 25
# Jane (Paper) vs Peter (Rock) -> Scores: Jane 20, Peter 34
# Jane (Scissors) vs Zoe (Paper) -> Scores: Jane 21, Zoe 25
# Peter (Scissors) vs Zoe (Scissors) -> Scores: Peter 34, Zoe 25
#
# Current standings:
# Jim -> Score: 20
# Jane -> Score: 21
# Peter -> Score: 34
# Zoe -> Score: 25
# ==================================================
# Jim (Rock) vs Jane (Rock) -> Scores: Jim 20, Jane 21
# Jim (Rock) vs Peter (Scissors) -> Scores: Jim 21, Peter 34
# Jim (Rock) vs Zoe (Rock) -> Scores: Jim 21, Zoe 25
# Jane (Rock) vs Peter (Scissors) -> Scores: Jane 22, Peter 34
# Jane (Scissors) vs Zoe (Rock) -> Scores: Jane 22, Zoe 26
# Peter (Paper) vs Zoe (Paper) -> Scores: Peter 34, Zoe 26
#
# Current standings:
# Jim -> Score: 21
# Jane -> Score: 22
# Peter -> Score: 34
# Zoe -> Score: 26
# ==================================================
# Jim (Rock) vs Jane (Paper) -> Scores: Jim 21, Jane 23
# Jim (Paper) vs Peter (Scissors) -> Scores: Jim 21, Peter 35
# Jim (Paper) vs Zoe (Scissors) -> Scores: Jim 21, Zoe 27
# Jane (Rock) vs Peter (Rock) -> Scores: Jane 23, Peter 35
# Jane (Scissors) vs Zoe (Paper) -> Scores: Jane 24, Zoe 27
# Peter (Scissors) vs Zoe (Scissors) -> Scores: Peter 35, Zoe 27
#
# Current standings:
# Jim -> Score: 21
# Jane -> Score: 24
# Peter -> Score: 35
# Zoe -> Score: 27
# ==================================================
# Jim (Paper) vs Jane (Paper) -> Scores: Jim 21, Jane 24
# Jim (Rock) vs Peter (Scissors) -> Scores: Jim 22, Peter 35
# Jim (Paper) vs Zoe (Paper) -> Scores: Jim 22, Zoe 27
# Jane (Paper) vs Peter (Paper) -> Scores: Jane 24, Peter 35
# Jane (Scissors) vs Zoe (Paper) -> Scores: Jane 25, Zoe 27
# Peter (Scissors) vs Zoe (Paper) -> Scores: Peter 36, Zoe 27
#
# Current standings:
# Jim -> Score: 22
# Jane -> Score: 25
# Peter -> Score: 36
# Zoe -> Score: 27
# ==================================================
# Jim (Scissors) vs Jane (Rock) -> Scores: Jim 22, Jane 26
# Jim (Scissors) vs Peter (Rock) -> Scores: Jim 22, Peter 37
# Jim (Rock) vs Zoe (Rock) -> Scores: Jim 22, Zoe 27
# Jane (Paper) vs Peter (Scissors) -> Scores: Jane 26, Peter 38
# Jane (Rock) vs Zoe (Rock) -> Scores: Jane 26, Zoe 27
# Peter (Rock) vs Zoe (Scissors) -> Scores: Peter 39, Zoe 27
#
# Current standings:
# Jim -> Score: 22
# Jane -> Score: 26
# Peter -> Score: 39
# Zoe -> Score: 27
# ==================================================
# Jim (Scissors) vs Jane (Scissors) -> Scores: Jim 22, Jane 26
# Jim (Scissors) vs Peter (Paper) -> Scores: Jim 23, Peter 39
# Jim (Scissors) vs Zoe (Rock) -> Scores: Jim 23, Zoe 28
# Jane (Scissors) vs Peter (Paper) -> Scores: Jane 27, Peter 39
# Jane (Rock) vs Zoe (Paper) -> Scores: Jane 27, Zoe 29
# Peter (Scissors) vs Zoe (Scissors) -> Scores: Peter 39, Zoe 29
#
# Current standings:
# Jim -> Score: 23
# Jane -> Score: 27
# Peter -> Score: 39
# Zoe -> Score: 29
# ==================================================
# Jim (Scissors) vs Jane (Rock) -> Scores: Jim 23, Jane 28
# Jim (Paper) vs Peter (Rock) -> Scores: Jim 24, Peter 39
# Jim (Scissors) vs Zoe (Rock) -> Scores: Jim 24, Zoe 30
# Jane (Scissors) vs Peter (Scissors) -> Scores: Jane 28, Peter 39
# Jane (Paper) vs Zoe (Scissors) -> Scores: Jane 28, Zoe 31
# Peter (Scissors) vs Zoe (Paper) -> Scores: Peter 40, Zoe 31
#
# Current standings:
# Jim -> Score: 24
# Jane -> Score: 28
# Peter -> Score: 40
# Zoe -> Score: 31
# ==================================================
# Jim (Rock) vs Jane (Rock) -> Scores: Jim 24, Jane 28
# Jim (Paper) vs Peter (Paper) -> Scores: Jim 24, Peter 40
# Jim (Rock) vs Zoe (Rock) -> Scores: Jim 24, Zoe 31
# Jane (Scissors) vs Peter (Scissors) -> Scores: Jane 28, Peter 40
# Jane (Scissors) vs Zoe (Scissors) -> Scores: Jane 28, Zoe 31
# Peter (Scissors) vs Zoe (Scissors) -> Scores: Peter 40, Zoe 31
#
# Current standings:
# Jim -> Score: 24
# Jane -> Score: 28
# Peter -> Score: 40
# Zoe -> Score: 31
# ==================================================
# Jim (Paper) vs Jane (Rock) -> Scores: Jim 25, Jane 28
# Jim (Paper) vs Peter (Scissors) -> Scores: Jim 25, Peter 41
# Jim (Rock) vs Zoe (Paper) -> Scores: Jim 25, Zoe 32
# Jane (Scissors) vs Peter (Rock) -> Scores: Jane 28, Peter 42
# Jane (Scissors) vs Zoe (Rock) -> Scores: Jane 28, Zoe 33
# Peter (Scissors) vs Zoe (Scissors) -> Scores: Peter 42, Zoe 33
#
# Current standings:
# Jim -> Score: 25
# Jane -> Score: 28
# Peter -> Score: 42
# Zoe -> Score: 33
# ==================================================
# Jim (Paper) vs Jane (Paper) -> Scores: Jim 25, Jane 28
# Jim (Rock) vs Peter (Rock) -> Scores: Jim 25, Peter 42
# Jim (Paper) vs Zoe (Rock) -> Scores: Jim 26, Zoe 33
# Jane (Rock) vs Peter (Paper) -> Scores: Jane 28, Peter 43
# Jane (Paper) vs Zoe (Scissors) -> Scores: Jane 28, Zoe 34
# Peter (Rock) vs Zoe (Rock) -> Scores: Peter 43, Zoe 34
#
# Current standings:
# Jim -> Score: 26
# Jane -> Score: 28
# Peter -> Score: 43
# Zoe -> Score: 34
# ==================================================
# Jim (Rock) vs Jane (Paper) -> Scores: Jim 26, Jane 29
# Jim (Rock) vs Peter (Paper) -> Scores: Jim 26, Peter 44
# Jim (Paper) vs Zoe (Rock) -> Scores: Jim 27, Zoe 34
# Jane (Paper) vs Peter (Paper) -> Scores: Jane 29, Peter 44
# Jane (Rock) vs Zoe (Scissors) -> Scores: Jane 30, Zoe 34
# Peter (Scissors) vs Zoe (Scissors) -> Scores: Peter 44, Zoe 34
#
# Current standings:
# Jim -> Score: 27
# Jane -> Score: 30
# Peter -> Score: 44
# Zoe -> Score: 34
# ==================================================
# Jim (Paper) vs Jane (Scissors) -> Scores: Jim 27, Jane 31
# Jim (Paper) vs Peter (Rock) -> Scores: Jim 28, Peter 44
# Jim (Paper) vs Zoe (Paper) -> Scores: Jim 28, Zoe 34
# Jane (Scissors) vs Peter (Paper) -> Scores: Jane 32, Peter 44
# Jane (Scissors) vs Zoe (Scissors) -> Scores: Jane 32, Zoe 34
# Peter (Paper) vs Zoe (Scissors) -> Scores: Peter 44, Zoe 35
#
# Current standings:
# Jim -> Score: 28
# Jane -> Score: 32
# Peter -> Score: 44
# Zoe -> Score: 35
# ==================================================
# Jim (Rock) vs Jane (Paper) -> Scores: Jim 28, Jane 33
# Jim (Scissors) vs Peter (Paper) -> Scores: Jim 29, Peter 44
# Jim (Scissors) vs Zoe (Scissors) -> Scores: Jim 29, Zoe 35
# Jane (Scissors) vs Peter (Scissors) -> Scores: Jane 33, Peter 44
# Jane (Rock) vs Zoe (Rock) -> Scores: Jane 33, Zoe 35
# Peter (Scissors) vs Zoe (Scissors) -> Scores: Peter 44, Zoe 35
#
# Current standings:
# Jim -> Score: 29
# Jane -> Score: 33
# Peter -> Score: 44
# Zoe -> Score: 35
# ==================================================
# Jim (Rock) vs Jane (Rock) -> Scores: Jim 29, Jane 33
# Jim (Rock) vs Peter (Scissors) -> Scores: Jim 30, Peter 44
# Jim (Rock) vs Zoe (Scissors) -> Scores: Jim 31, Zoe 35
# Jane (Paper) vs Peter (Paper) -> Scores: Jane 33, Peter 44
# Jane (Rock) vs Zoe (Scissors) -> Scores: Jane 34, Zoe 35
# Peter (Scissors) vs Zoe (Rock) -> Scores: Peter 44, Zoe 36
#
# Current standings:
# Jim -> Score: 31
# Jane -> Score: 34
# Peter -> Score: 44
# Zoe -> Score: 36
# ==================================================
# Jim (Scissors) vs Jane (Scissors) -> Scores: Jim 31, Jane 34
# Jim (Rock) vs Peter (Paper) -> Scores: Jim 31, Peter 45
# Jim (Scissors) vs Zoe (Scissors) -> Scores: Jim 31, Zoe 36
# Jane (Rock) vs Peter (Scissors) -> Scores: Jane 35, Peter 45
# Jane (Rock) vs Zoe (Scissors) -> Scores: Jane 36, Zoe 36
# Peter (Rock) vs Zoe (Paper) -> Scores: Peter 45, Zoe 37
#
# Current standings:
# Jim -> Score: 31
# Jane -> Score: 36
# Peter -> Score: 45
# Zoe -> Score: 37
# ==================================================
# Jim (Paper) vs Jane (Paper) -> Scores: Jim 31, Jane 36
# Jim (Rock) vs Peter (Paper) -> Scores: Jim 31, Peter 46
# Jim (Rock) vs Zoe (Paper) -> Scores: Jim 31, Zoe 38
# Jane (Scissors) vs Peter (Scissors) -> Scores: Jane 36, Peter 46
# Jane (Paper) vs Zoe (Scissors) -> Scores: Jane 36, Zoe 39
# Peter (Paper) vs Zoe (Rock) -> Scores: Peter 47, Zoe 39
#
# Current standings:
# Jim -> Score: 31
# Jane -> Score: 36
# Peter -> Score: 47
# Zoe -> Score: 39
# ==================================================
# Jim (Paper) vs Jane (Scissors) -> Scores: Jim 31, Jane 37
# Jim (Paper) vs Peter (Rock) -> Scores: Jim 32, Peter 47
# Jim (Scissors) vs Zoe (Scissors) -> Scores: Jim 32, Zoe 39
# Jane (Paper) vs Peter (Scissors) -> Scores: Jane 37, Peter 48
# Jane (Scissors) vs Zoe (Rock) -> Scores: Jane 37, Zoe 40
# Peter (Paper) vs Zoe (Scissors) -> Scores: Peter 48, Zoe 41
#
# Current standings:
# Jim -> Score: 32
# Jane -> Score: 37
# Peter -> Score: 48
# Zoe -> Score: 41
# ==================================================
# Jim (Rock) vs Jane (Paper) -> Scores: Jim 32, Jane 38
# Jim (Scissors) vs Peter (Scissors) -> Scores: Jim 32, Peter 48
# Jim (Paper) vs Zoe (Paper) -> Scores: Jim 32, Zoe 41
# Jane (Rock) vs Peter (Rock) -> Scores: Jane 38, Peter 48
# Jane (Scissors) vs Zoe (Paper) -> Scores: Jane 39, Zoe 41
# Peter (Rock) vs Zoe (Scissors) -> Scores: Peter 49, Zoe 41
#
# Current standings:
# Jim -> Score: 32
# Jane -> Score: 39
# Peter -> Score: 49
# Zoe -> Score: 41
# ==================================================
# Jim (Rock) vs Jane (Paper) -> Scores: Jim 32, Jane 40
# Jim (Scissors) vs Peter (Scissors) -> Scores: Jim 32, Peter 49
# Jim (Rock) vs Zoe (Paper) -> Scores: Jim 32, Zoe 42
# Jane (Paper) vs Peter (Scissors) -> Scores: Jane 40, Peter 50
# Jane (Rock) vs Zoe (Scissors) -> Scores: Jane 41, Zoe 42
# Peter (Rock) vs Zoe (Scissors) -> Scores: Peter 51, Zoe 42
#
# Current standings:
# Jim -> Score: 32
# Jane -> Score: 41
# Peter -> Score: 51
# Zoe -> Score: 42
# ==================================================
# Jim (Rock) vs Jane (Rock) -> Scores: Jim 32, Jane 41
# Jim (Scissors) vs Peter (Scissors) -> Scores: Jim 32, Peter 51
# Jim (Rock) vs Zoe (Scissors) -> Scores: Jim 33, Zoe 42
# Jane (Scissors) vs Peter (Scissors) -> Scores: Jane 41, Peter 51
# Jane (Rock) vs Zoe (Scissors) -> Scores: Jane 42, Zoe 42
# Peter (Scissors) vs Zoe (Rock) -> Scores: Peter 51, Zoe 43
#
# Current standings:
# Jim -> Score: 33
# Jane -> Score: 42
# Peter -> Score: 51
# Zoe -> Score: 43
# ==================================================
# Jim (Rock) vs Jane (Scissors) -> Scores: Jim 34, Jane 42
# Jim (Paper) vs Peter (Rock) -> Scores: Jim 35, Peter 51
# Jim (Rock) vs Zoe (Paper) -> Scores: Jim 35, Zoe 44
# Jane (Rock) vs Peter (Rock) -> Scores: Jane 42, Peter 51
# Jane (Paper) vs Zoe (Paper) -> Scores: Jane 42, Zoe 44
# Peter (Scissors) vs Zoe (Rock) -> Scores: Peter 51, Zoe 45
#
# Current standings:
# Jim -> Score: 35
# Jane -> Score: 42
# Peter -> Score: 51
# Zoe -> Score: 45
# ==================================================
# Jim (Scissors) vs Jane (Paper) -> Scores: Jim 36, Jane 42
# Jim (Paper) vs Peter (Rock) -> Scores: Jim 37, Peter 51
# Jim (Rock) vs Zoe (Scissors) -> Scores: Jim 38, Zoe 45
# Jane (Rock) vs Peter (Scissors) -> Scores: Jane 43, Peter 51
# Jane (Paper) vs Zoe (Scissors) -> Scores: Jane 43, Zoe 46
# Peter (Scissors) vs Zoe (Rock) -> Scores: Peter 51, Zoe 47
#
# Current standings:
# Jim -> Score: 38
# Jane -> Score: 43
# Peter -> Score: 51
# Zoe -> Score: 47
# ==================================================
# Jim (Scissors) vs Jane (Rock) -> Scores: Jim 38, Jane 44
# Jim (Paper) vs Peter (Paper) -> Scores: Jim 38, Peter 51
# Jim (Rock) vs Zoe (Rock) -> Scores: Jim 38, Zoe 47
# Jane (Scissors) vs Peter (Paper) -> Scores: Jane 45, Peter 51
# Jane (Paper) vs Zoe (Paper) -> Scores: Jane 45, Zoe 47
# Peter (Rock) vs Zoe (Rock) -> Scores: Peter 51, Zoe 47
#
# Current standings:
# Jim -> Score: 38
# Jane -> Score: 45
# Peter -> Score: 51
# Zoe -> Score: 47
# ==================================================
# Jim (Scissors) vs Jane (Paper) -> Scores: Jim 39, Jane 45
# Jim (Rock) vs Peter (Rock) -> Scores: Jim 39, Peter 51
# Jim (Scissors) vs Zoe (Rock) -> Scores: Jim 39, Zoe 48
# Jane (Rock) vs Peter (Paper) -> Scores: Jane 45, Peter 52
# Jane (Paper) vs Zoe (Rock) -> Scores: Jane 46, Zoe 48
# Peter (Paper) vs Zoe (Rock) -> Scores: Peter 53, Zoe 48
#
# Current standings:
# Jim -> Score: 39
# Jane -> Score: 46
# Peter -> Score: 53
# Zoe -> Score: 48
# ==================================================
# Jim (Rock) vs Jane (Rock) -> Scores: Jim 39, Jane 46
# Jim (Paper) vs Peter (Rock) -> Scores: Jim 40, Peter 53
# Jim (Rock) vs Zoe (Rock) -> Scores: Jim 40, Zoe 48
# Jane (Scissors) vs Peter (Rock) -> Scores: Jane 46, Peter 54
# Jane (Scissors) vs Zoe (Paper) -> Scores: Jane 47, Zoe 48
# Peter (Scissors) vs Zoe (Paper) -> Scores: Peter 55, Zoe 48
#
# Current standings:
# Jim -> Score: 40
# Jane -> Score: 47
# Peter -> Score: 55
# Zoe -> Score: 48
# ==================================================
# Jim (Rock) vs Jane (Scissors) -> Scores: Jim 41, Jane 47
# Jim (Rock) vs Peter (Rock) -> Scores: Jim 41, Peter 55
# Jim (Paper) vs Zoe (Scissors) -> Scores: Jim 41, Zoe 49
# Jane (Scissors) vs Peter (Scissors) -> Scores: Jane 47, Peter 55
# Jane (Rock) vs Zoe (Scissors) -> Scores: Jane 48, Zoe 49
# Peter (Paper) vs Zoe (Scissors) -> Scores: Peter 55, Zoe 50
#
# Current standings:
# Jim -> Score: 41
# Jane -> Score: 48
# Peter -> Score: 55
# Zoe -> Score: 50
# ==================================================
# Jim (Rock) vs Jane (Paper) -> Scores: Jim 41, Jane 49
# Jim (Scissors) vs Peter (Scissors) -> Scores: Jim 41, Peter 55
# Jim (Rock) vs Zoe (Paper) -> Scores: Jim 41, Zoe 51
# Jane (Paper) vs Peter (Paper) -> Scores: Jane 49, Peter 55
# Jane (Scissors) vs Zoe (Rock) -> Scores: Jane 49, Zoe 52
# Peter (Scissors) vs Zoe (Scissors) -> Scores: Peter 55, Zoe 52
#
# Current standings:
# Jim -> Score: 41
# Jane -> Score: 49
# Peter -> Score: 55
# Zoe -> Score: 52
# ==================================================
# Jim (Paper) vs Jane (Scissors) -> Scores: Jim 41, Jane 50
# Jim (Rock) vs Peter (Rock) -> Scores: Jim 41, Peter 55
# Jim (Paper) vs Zoe (Scissors) -> Scores: Jim 41, Zoe 53
# Jane (Paper) vs Peter (Scissors) -> Scores: Jane 50, Peter 56
# Jane (Rock) vs Zoe (Rock) -> Scores: Jane 50, Zoe 53
# Peter (Scissors) vs Zoe (Scissors) -> Scores: Peter 56, Zoe 53
#
# Current standings:
# Jim -> Score: 41
# Jane -> Score: 50
# Peter -> Score: 56
# Zoe -> Score: 53
# ==================================================
# Jim (Paper) vs Jane (Paper) -> Scores: Jim 41, Jane 50
# Jim (Scissors) vs Peter (Scissors) -> Scores: Jim 41, Peter 56
# Jim (Scissors) vs Zoe (Paper) -> Scores: Jim 42, Zoe 53
# Jane (Paper) vs Peter (Paper) -> Scores: Jane 50, Peter 56
# Jane (Paper) vs Zoe (Scissors) -> Scores: Jane 50, Zoe 54
# Peter (Paper) vs Zoe (Rock) -> Scores: Peter 57, Zoe 54
#
# Current standings:
# Jim -> Score: 42
# Jane -> Score: 50
# Peter -> Score: 57
# Zoe -> Score: 54
# ==================================================
# Jim (Rock) vs Jane (Paper) -> Scores: Jim 42, Jane 51
# Jim (Scissors) vs Peter (Paper) -> Scores: Jim 43, Peter 57
# Jim (Scissors) vs Zoe (Rock) -> Scores: Jim 43, Zoe 55
# Jane (Paper) vs Peter (Paper) -> Scores: Jane 51, Peter 57
# Jane (Paper) vs Zoe (Scissors) -> Scores: Jane 51, Zoe 56
# Peter (Paper) vs Zoe (Scissors) -> Scores: Peter 57, Zoe 57
#
# Current standings:
# Jim -> Score: 43
# Jane -> Score: 51
# Peter -> Score: 57
# Zoe -> Score: 57
# ==================================================
# Jim (Paper) vs Jane (Paper) -> Scores: Jim 43, Jane 51
# Jim (Rock) vs Peter (Rock) -> Scores: Jim 43, Peter 57
# Jim (Rock) vs Zoe (Rock) -> Scores: Jim 43, Zoe 57
# Jane (Paper) vs Peter (Rock) -> Scores: Jane 52, Peter 57
# Jane (Rock) vs Zoe (Rock) -> Scores: Jane 52, Zoe 57
# Peter (Scissors) vs Zoe (Rock) -> Scores: Peter 57, Zoe 58
#
# Current standings:
# Jim -> Score: 43
# Jane -> Score: 52
# Peter -> Score: 57
# Zoe -> Score: 58
# ==================================================
# Jim (Paper) vs Jane (Rock) -> Scores: Jim 44, Jane 52
# Jim (Scissors) vs Peter (Scissors) -> Scores: Jim 44, Peter 57
# Jim (Paper) vs Zoe (Rock) -> Scores: Jim 45, Zoe 58
# Jane (Scissors) vs Peter (Scissors) -> Scores: Jane 52, Peter 57
# Jane (Scissors) vs Zoe (Rock) -> Scores: Jane 52, Zoe 59
# Peter (Rock) vs Zoe (Paper) -> Scores: Peter 57, Zoe 60
#
# Current standings:
# Jim -> Score: 45
# Jane -> Score: 52
# Peter -> Score: 57
# Zoe -> Score: 60
# ==================================================
# Jim (Paper) vs Jane (Paper) -> Scores: Jim 45, Jane 52
# Jim (Scissors) vs Peter (Paper) -> Scores: Jim 46, Peter 57
# Jim (Rock) vs Zoe (Rock) -> Scores: Jim 46, Zoe 60
# Jane (Rock) vs Peter (Paper) -> Scores: Jane 52, Peter 58
# Jane (Scissors) vs Zoe (Rock) -> Scores: Jane 52, Zoe 61
# Peter (Rock) vs Zoe (Paper) -> Scores: Peter 58, Zoe 62
#
# Current standings:
# Jim -> Score: 46
# Jane -> Score: 52
# Peter -> Score: 58
# Zoe -> Score: 62
# ==================================================
# Jim (Scissors) vs Jane (Paper) -> Scores: Jim 47, Jane 52
# Jim (Scissors) vs Peter (Rock) -> Scores: Jim 47, Peter 59
# Jim (Scissors) vs Zoe (Scissors) -> Scores: Jim 47, Zoe 62
# Jane (Paper) vs Peter (Scissors) -> Scores: Jane 52, Peter 60
# Jane (Paper) vs Zoe (Rock) -> Scores: Jane 53, Zoe 62
# Peter (Rock) vs Zoe (Rock) -> Scores: Peter 60, Zoe 62
#
# Current standings:
# Jim -> Score: 47
# Jane -> Score: 53
# Peter -> Score: 60
# Zoe -> Score: 62
# ==================================================
# Jim (Paper) vs Jane (Paper) -> Scores: Jim 47, Jane 53
# Jim (Scissors) vs Peter (Rock) -> Scores: Jim 47, Peter 61
# Jim (Scissors) vs Zoe (Paper) -> Scores: Jim 48, Zoe 62
# Jane (Rock) vs Peter (Scissors) -> Scores: Jane 54, Peter 61
# Jane (Rock) vs Zoe (Paper) -> Scores: Jane 54, Zoe 63
# Peter (Paper) vs Zoe (Paper) -> Scores: Peter 61, Zoe 63
#
# Current standings:
# Jim -> Score: 48
# Jane -> Score: 54
# Peter -> Score: 61
# Zoe -> Score: 63
# ==================================================
# Jim (Paper) vs Jane (Scissors) -> Scores: Jim 48, Jane 55
# Jim (Scissors) vs Peter (Scissors) -> Scores: Jim 48, Peter 61
# Jim (Rock) vs Zoe (Paper) -> Scores: Jim 48, Zoe 64
# Jane (Scissors) vs Peter (Scissors) -> Scores: Jane 55, Peter 61
# Jane (Rock) vs Zoe (Paper) -> Scores: Jane 55, Zoe 65
# Peter (Rock) vs Zoe (Rock) -> Scores: Peter 61, Zoe 65
#
# Current standings:
# Jim -> Score: 48
# Jane -> Score: 55
# Peter -> Score: 61
# Zoe -> Score: 65
# ==================================================
# Jim (Paper) vs Jane (Scissors) -> Scores: Jim 48, Jane 56
# Jim (Scissors) vs Peter (Scissors) -> Scores: Jim 48, Peter 61
# Jim (Scissors) vs Zoe (Rock) -> Scores: Jim 48, Zoe 66
# Jane (Scissors) vs Peter (Paper) -> Scores: Jane 57, Peter 61
# Jane (Paper) vs Zoe (Rock) -> Scores: Jane 58, Zoe 66
# Peter (Rock) vs Zoe (Paper) -> Scores: Peter 61, Zoe 67
#
# Current standings:
# Jim -> Score: 48
# Jane -> Score: 58
# Peter -> Score: 61
# Zoe -> Score: 67
# ==================================================
# Jim (Rock) vs Jane (Scissors) -> Scores: Jim 49, Jane 58
# Jim (Rock) vs Peter (Scissors) -> Scores: Jim 50, Peter 61
# Jim (Paper) vs Zoe (Paper) -> Scores: Jim 50, Zoe 67
# Jane (Scissors) vs Peter (Paper) -> Scores: Jane 59, Peter 61
# Jane (Rock) vs Zoe (Scissors) -> Scores: Jane 60, Zoe 67
# Peter (Paper) vs Zoe (Paper) -> Scores: Peter 61, Zoe 67
#
# Current standings:
# Jim -> Score: 50
# Jane -> Score: 60
# Peter -> Score: 61
# Zoe -> Score: 67
# ==================================================
# Jim (Paper) vs Jane (Paper) -> Scores: Jim 50, Jane 60
# Jim (Rock) vs Peter (Paper) -> Scores: Jim 50, Peter 62
# Jim (Paper) vs Zoe (Rock) -> Scores: Jim 51, Zoe 67
# Jane (Scissors) vs Peter (Scissors) -> Scores: Jane 60, Peter 62
# Jane (Scissors) vs Zoe (Paper) -> Scores: Jane 61, Zoe 67
# Peter (Paper) vs Zoe (Paper) -> Scores: Peter 62, Zoe 67
#
# Current standings:
# Jim -> Score: 51
# Jane -> Score: 61
# Peter -> Score: 62
# Zoe -> Score: 67
# ==================================================
# Jim (Paper) vs Jane (Rock) -> Scores: Jim 52, Jane 61
# Jim (Rock) vs Peter (Rock) -> Scores: Jim 52, Peter 62
# Jim (Paper) vs Zoe (Rock) -> Scores: Jim 53, Zoe 67
# Jane (Paper) vs Peter (Paper) -> Scores: Jane 61, Peter 62
# Jane (Scissors) vs Zoe (Rock) -> Scores: Jane 61, Zoe 68
# Peter (Paper) vs Zoe (Rock) -> Scores: Peter 63, Zoe 68
#
# Current standings:
# Jim -> Score: 53
# Jane -> Score: 61
# Peter -> Score: 63
# Zoe -> Score: 68
# ==================================================
# Jim (Rock) vs Jane (Rock) -> Scores: Jim 53, Jane 61
# Jim (Scissors) vs Peter (Scissors) -> Scores: Jim 53, Peter 63
# Jim (Scissors) vs Zoe (Rock) -> Scores: Jim 53, Zoe 69
# Jane (Scissors) vs Peter (Rock) -> Scores: Jane 61, Peter 64
# Jane (Paper) vs Zoe (Paper) -> Scores: Jane 61, Zoe 69
# Peter (Paper) vs Zoe (Scissors) -> Scores: Peter 64, Zoe 70
#
# Current standings:
# Jim -> Score: 53
# Jane -> Score: 61
# Peter -> Score: 64
# Zoe -> Score: 70
# ==================================================
# Jim (Scissors) vs Jane (Rock) -> Scores: Jim 53, Jane 62
# Jim (Rock) vs Peter (Paper) -> Scores: Jim 53, Peter 65
# Jim (Paper) vs Zoe (Rock) -> Scores: Jim 54, Zoe 70
# Jane (Rock) vs Peter (Rock) -> Scores: Jane 62, Peter 65
# Jane (Scissors) vs Zoe (Rock) -> Scores: Jane 62, Zoe 71
# Peter (Rock) vs Zoe (Rock) -> Scores: Peter 65, Zoe 71
#
# Current standings:
# Jim -> Score: 54
# Jane -> Score: 62
# Peter -> Score: 65
# Zoe -> Score: 71
# ==================================================
# Jim (Rock) vs Jane (Scissors) -> Scores: Jim 55, Jane 62
# Jim (Rock) vs Peter (Scissors) -> Scores: Jim 56, Peter 65
# Jim (Scissors) vs Zoe (Paper) -> Scores: Jim 57, Zoe 71
# Jane (Paper) vs Peter (Paper) -> Scores: Jane 62, Peter 65
# Jane (Rock) vs Zoe (Rock) -> Scores: Jane 62, Zoe 71
# Peter (Paper) vs Zoe (Scissors) -> Scores: Peter 65, Zoe 72
#
# Current standings:
# Jim -> Score: 57
# Jane -> Score: 62
# Peter -> Score: 65
# Zoe -> Score: 72
# ==================================================
# Jim (Scissors) vs Jane (Paper) -> Scores: Jim 58, Jane 62
# Jim (Paper) vs Peter (Scissors) -> Scores: Jim 58, Peter 66
# Jim (Rock) vs Zoe (Rock) -> Scores: Jim 58, Zoe 72
# Jane (Rock) vs Peter (Rock) -> Scores: Jane 62, Peter 66
# Jane (Paper) vs Zoe (Scissors) -> Scores: Jane 62, Zoe 73
# Peter (Scissors) vs Zoe (Rock) -> Scores: Peter 66, Zoe 74
#
# Current standings:
# Jim -> Score: 58
# Jane -> Score: 62
# Peter -> Score: 66
# Zoe -> Score: 74
# ==================================================
# Jim (Rock) vs Jane (Paper) -> Scores: Jim 58, Jane 63
# Jim (Paper) vs Peter (Paper) -> Scores: Jim 58, Peter 66
# Jim (Rock) vs Zoe (Rock) -> Scores: Jim 58, Zoe 74
# Jane (Rock) vs Peter (Paper) -> Scores: Jane 63, Peter 67
# Jane (Paper) vs Zoe (Paper) -> Scores: Jane 63, Zoe 74
# Peter (Rock) vs Zoe (Paper) -> Scores: Peter 67, Zoe 75
#
# Current standings:
# Jim -> Score: 58
# Jane -> Score: 63
# Peter -> Score: 67
# Zoe -> Score: 75
# ==================================================
# Jim (Scissors) vs Jane (Scissors) -> Scores: Jim 58, Jane 63
# Jim (Rock) vs Peter (Paper) -> Scores: Jim 58, Peter 68
# Jim (Scissors) vs Zoe (Paper) -> Scores: Jim 59, Zoe 75
# Jane (Paper) vs Peter (Scissors) -> Scores: Jane 63, Peter 69
# Jane (Rock) vs Zoe (Paper) -> Scores: Jane 63, Zoe 76
# Peter (Rock) vs Zoe (Paper) -> Scores: Peter 69, Zoe 77
#
# Current standings:
# Jim -> Score: 59
# Jane -> Score: 63
# Peter -> Score: 69
# Zoe -> Score: 77
# ==================================================
# Jim (Rock) vs Jane (Rock) -> Scores: Jim 59, Jane 63
# Jim (Scissors) vs Peter (Rock) -> Scores: Jim 59, Peter 70
# Jim (Paper) vs Zoe (Scissors) -> Scores: Jim 59, Zoe 78
# Jane (Paper) vs Peter (Scissors) -> Scores: Jane 63, Peter 71
# Jane (Paper) vs Zoe (Paper) -> Scores: Jane 63, Zoe 78
# Peter (Scissors) vs Zoe (Rock) -> Scores: Peter 71, Zoe 79
#
# Current standings:
# Jim -> Score: 59
# Jane -> Score: 63
# Peter -> Score: 71
# Zoe -> Score: 79
# ==================================================
# Jim (Paper) vs Jane (Rock) -> Scores: Jim 60, Jane 63
# Jim (Scissors) vs Peter (Scissors) -> Scores: Jim 60, Peter 71
# Jim (Scissors) vs Zoe (Rock) -> Scores: Jim 60, Zoe 80
# Jane (Paper) vs Peter (Scissors) -> Scores: Jane 63, Peter 72
# Jane (Rock) vs Zoe (Paper) -> Scores: Jane 63, Zoe 81
# Peter (Paper) vs Zoe (Rock) -> Scores: Peter 73, Zoe 81
#
# Current standings:
# Jim -> Score: 60
# Jane -> Score: 63
# Peter -> Score: 73
# Zoe -> Score: 81
# ==================================================
# Jim (Rock) vs Jane (Rock) -> Scores: Jim 60, Jane 63
# Jim (Paper) vs Peter (Scissors) -> Scores: Jim 60, Peter 74
# Jim (Rock) vs Zoe (Paper) -> Scores: Jim 60, Zoe 82
# Jane (Scissors) vs Peter (Paper) -> Scores: Jane 64, Peter 74
# Jane (Rock) vs Zoe (Paper) -> Scores: Jane 64, Zoe 83
# Peter (Paper) vs Zoe (Paper) -> Scores: Peter 74, Zoe 83
#
# Current standings:
# Jim -> Score: 60
# Jane -> Score: 64
# Peter -> Score: 74
# Zoe -> Score: 83
# ==================================================
# Jim (Scissors) vs Jane (Scissors) -> Scores: Jim 60, Jane 64
# Jim (Rock) vs Peter (Scissors) -> Scores: Jim 61, Peter 74
# Jim (Scissors) vs Zoe (Rock) -> Scores: Jim 61, Zoe 84
# Jane (Paper) vs Peter (Scissors) -> Scores: Jane 64, Peter 75
# Jane (Scissors) vs Zoe (Paper) -> Scores: Jane 65, Zoe 84
# Peter (Rock) vs Zoe (Paper) -> Scores: Peter 75, Zoe 85
#
# Current standings:
# Jim -> Score: 61
# Jane -> Score: 65
# Peter -> Score: 75
# Zoe -> Score: 85
# ==================================================
# Jim (Rock) vs Jane (Scissors) -> Scores: Jim 62, Jane 65
# Jim (Scissors) vs Peter (Paper) -> Scores: Jim 63, Peter 75
# Jim (Paper) vs Zoe (Rock) -> Scores: Jim 64, Zoe 85
# Jane (Paper) vs Peter (Paper) -> Scores: Jane 65, Peter 75
# Jane (Rock) vs Zoe (Paper) -> Scores: Jane 65, Zoe 86
# Peter (Scissors) vs Zoe (Paper) -> Scores: Peter 76, Zoe 86
#
# Current standings:
# Jim -> Score: 64
# Jane -> Score: 65
# Peter -> Score: 76
# Zoe -> Score: 86
# ==================================================
# Jim (Rock) vs Jane (Paper) -> Scores: Jim 64, Jane 66
# Jim (Paper) vs Peter (Rock) -> Scores: Jim 65, Peter 76
# Jim (Scissors) vs Zoe (Paper) -> Scores: Jim 66, Zoe 86
# Jane (Rock) vs Peter (Paper) -> Scores: Jane 66, Peter 77
# Jane (Rock) vs Zoe (Rock) -> Scores: Jane 66, Zoe 86
# Peter (Paper) vs Zoe (Scissors) -> Scores: Peter 77, Zoe 87
#
# Current standings:
# Jim -> Score: 66
# Jane -> Score: 66
# Peter -> Score: 77
# Zoe -> Score: 87
# ==================================================
# Jim (Rock) vs Jane (Rock) -> Scores: Jim 66, Jane 66
# Jim (Scissors) vs Peter (Paper) -> Scores: Jim 67, Peter 77
# Jim (Scissors) vs Zoe (Scissors) -> Scores: Jim 67, Zoe 87
# Jane (Scissors) vs Peter (Scissors) -> Scores: Jane 66, Peter 77
# Jane (Scissors) vs Zoe (Paper) -> Scores: Jane 67, Zoe 87
# Peter (Paper) vs Zoe (Scissors) -> Scores: Peter 77, Zoe 88
#
# Current standings:
# Jim -> Score: 67
# Jane -> Score: 67
# Peter -> Score: 77
# Zoe -> Score: 88
# ==================================================
# Jim (Rock) vs Jane (Rock) -> Scores: Jim 67, Jane 67
# Jim (Scissors) vs Peter (Paper) -> Scores: Jim 68, Peter 77
# Jim (Paper) vs Zoe (Rock) -> Scores: Jim 69, Zoe 88
# Jane (Rock) vs Peter (Paper) -> Scores: Jane 67, Peter 78
# Jane (Paper) vs Zoe (Rock) -> Scores: Jane 68, Zoe 88
# Peter (Scissors) vs Zoe (Rock) -> Scores: Peter 78, Zoe 89
#
# Current standings:
# Jim -> Score: 69
# Jane -> Score: 68
# Peter -> Score: 78
# Zoe -> Score: 89
# ==================================================
# Jim (Scissors) vs Jane (Rock) -> Scores: Jim 69, Jane 69
# Jim (Paper) vs Peter (Paper) -> Scores: Jim 69, Peter 78
# Jim (Scissors) vs Zoe (Paper) -> Scores: Jim 70, Zoe 89
# Jane (Rock) vs Peter (Scissors) -> Scores: Jane 70, Peter 78
# Jane (Paper) vs Zoe (Paper) -> Scores: Jane 70, Zoe 89
# Peter (Scissors) vs Zoe (Paper) -> Scores: Peter 79, Zoe 89
#
# Current standings:
# Jim -> Score: 70
# Jane -> Score: 70
# Peter -> Score: 79
# Zoe -> Score: 89
# ==================================================
# Jim (Paper) vs Jane (Paper) -> Scores: Jim 70, Jane 70
# Jim (Rock) vs Peter (Rock) -> Scores: Jim 70, Peter 79
# Jim (Paper) vs Zoe (Rock) -> Scores: Jim 71, Zoe 89
# Jane (Rock) vs Peter (Paper) -> Scores: Jane 70, Peter 80
# Jane (Paper) vs Zoe (Scissors) -> Scores: Jane 70, Zoe 90
# Peter (Paper) vs Zoe (Scissors) -> Scores: Peter 80, Zoe 91
#
# Current standings:
# Jim -> Score: 71
# Jane -> Score: 70
# Peter -> Score: 80
# Zoe -> Score: 91
# ==================================================
# Jim (Scissors) vs Jane (Rock) -> Scores: Jim 71, Jane 71
# Jim (Paper) vs Peter (Scissors) -> Scores: Jim 71, Peter 81
# Jim (Paper) vs Zoe (Scissors) -> Scores: Jim 71, Zoe 92
# Jane (Rock) vs Peter (Paper) -> Scores: Jane 71, Peter 82
# Jane (Paper) vs Zoe (Paper) -> Scores: Jane 71, Zoe 92
# Peter (Paper) vs Zoe (Paper) -> Scores: Peter 82, Zoe 92
#
# Current standings:
# Jim -> Score: 71
# Jane -> Score: 71
# Peter -> Score: 82
# Zoe -> Score: 92
# ==================================================
# Jim (Scissors) vs Jane (Paper) -> Scores: Jim 72, Jane 71
# Jim (Rock) vs Peter (Paper) -> Scores: Jim 72, Peter 83
# Jim (Paper) vs Zoe (Paper) -> Scores: Jim 72, Zoe 92
# Jane (Rock) vs Peter (Paper) -> Scores: Jane 71, Peter 84
# Jane (Paper) vs Zoe (Scissors) -> Scores: Jane 71, Zoe 93
# Peter (Rock) vs Zoe (Paper) -> Scores: Peter 84, Zoe 94
#
# Current standings:
# Jim -> Score: 72
# Jane -> Score: 71
# Peter -> Score: 84
# Zoe -> Score: 94
# ==================================================
# Jim (Rock) vs Jane (Scissors) -> Scores: Jim 73, Jane 71
# Jim (Paper) vs Peter (Scissors) -> Scores: Jim 73, Peter 85
# Jim (Paper) vs Zoe (Scissors) -> Scores: Jim 73, Zoe 95
# Jane (Rock) vs Peter (Scissors) -> Scores: Jane 72, Peter 85
# Jane (Paper) vs Zoe (Rock) -> Scores: Jane 73, Zoe 95
# Peter (Scissors) vs Zoe (Paper) -> Scores: Peter 86, Zoe 95
#
# Current standings:
# Jim -> Score: 73
# Jane -> Score: 73
# Peter -> Score: 86
# Zoe -> Score: 95
# ==================================================
# Jim (Rock) vs Jane (Paper) -> Scores: Jim 73, Jane 74
# Jim (Paper) vs Peter (Paper) -> Scores: Jim 73, Peter 86
# Jim (Scissors) vs Zoe (Rock) -> Scores: Jim 73, Zoe 96
# Jane (Rock) vs Peter (Rock) -> Scores: Jane 74, Peter 86
# Jane (Scissors) vs Zoe (Rock) -> Scores: Jane 74, Zoe 97
# Peter (Rock) vs Zoe (Paper) -> Scores: Peter 86, Zoe 98
#
# Current standings:
# Jim -> Score: 73
# Jane -> Score: 74
# Peter -> Score: 86
# Zoe -> Score: 98
# ==================================================
# Jim (Rock) vs Jane (Paper) -> Scores: Jim 73, Jane 75
# Jim (Rock) vs Peter (Paper) -> Scores: Jim 73, Peter 87
# Jim (Scissors) vs Zoe (Paper) -> Scores: Jim 74, Zoe 98
# Jane (Paper) vs Peter (Paper) -> Scores: Jane 75, Peter 87
# Jane (Rock) vs Zoe (Paper) -> Scores: Jane 75, Zoe 99
# Peter (Scissors) vs Zoe (Rock) -> Scores: Peter 87, Zoe 100
#
# Current standings:
# Jim -> Score: 74
# Jane -> Score: 75
# Peter -> Score: 87
# Zoe -> Score: 100
# ==================================================
# Jim (Paper) vs Jane (Scissors) -> Scores: Jim 74, Jane 76
# Jim (Paper) vs Peter (Scissors) -> Scores: Jim 74, Peter 88
# Jim (Paper) vs Zoe (Paper) -> Scores: Jim 74, Zoe 100
# Jane (Rock) vs Peter (Scissors) -> Scores: Jane 77, Peter 88
# Jane (Scissors) vs Zoe (Paper) -> Scores: Jane 78, Zoe 100
# Peter (Paper) vs Zoe (Paper) -> Scores: Peter 88, Zoe 100
#
# Current standings:
# Jim -> Score: 74
# Jane -> Score: 78
# Peter -> Score: 88
# Zoe -> Score: 100
# ==================================================
# Jim (Scissors) vs Jane (Scissors) -> Scores: Jim 74, Jane 78
# Jim (Paper) vs Peter (Paper) -> Scores: Jim 74, Peter 88
# Jim (Paper) vs Zoe (Paper) -> Scores: Jim 74, Zoe 100
# Jane (Paper) vs Peter (Paper) -> Scores: Jane 78, Peter 88
# Jane (Rock) vs Zoe (Scissors) -> Scores: Jane 79, Zoe 100
# Peter (Scissors) vs Zoe (Scissors) -> Scores: Peter 88, Zoe 100
#
# Current standings:
# Jim -> Score: 74
# Jane -> Score: 79
# Peter -> Score: 88
# Zoe -> Score: 100
# ==================================================
# Jim (Paper) vs Jane (Scissors) -> Scores: Jim 74, Jane 80
# Jim (Rock) vs Peter (Paper) -> Scores: Jim 74, Peter 89
# Jim (Scissors) vs Zoe (Rock) -> Scores: Jim 74, Zoe 101
# Jane (Paper) vs Peter (Rock) -> Scores: Jane 81, Peter 89
# Jane (Paper) vs Zoe (Rock) -> Scores: Jane 82, Zoe 101
# Peter (Paper) vs Zoe (Scissors) -> Scores: Peter 89, Zoe 102
#
# Current standings:
# Jim -> Score: 74
# Jane -> Score: 82
# Peter -> Score: 89
# Zoe -> Score: 102
# ==================================================
# Jim (Paper) vs Jane (Rock) -> Scores: Jim 75, Jane 82
# Jim (Paper) vs Peter (Rock) -> Scores: Jim 76, Peter 89
# Jim (Paper) vs Zoe (Scissors) -> Scores: Jim 76, Zoe 103
# Jane (Scissors) vs Peter (Rock) -> Scores: Jane 82, Peter 90
# Jane (Rock) vs Zoe (Paper) -> Scores: Jane 82, Zoe 104
# Peter (Scissors) vs Zoe (Paper) -> Scores: Peter 91, Zoe 104
#
# Current standings:
# Jim -> Score: 76
# Jane -> Score: 82
# Peter -> Score: 91
# Zoe -> Score: 104
# ==================================================
# Jim (Rock) vs Jane (Rock) -> Scores: Jim 76, Jane 82
# Jim (Paper) vs Peter (Rock) -> Scores: Jim 77, Peter 91
# Jim (Paper) vs Zoe (Paper) -> Scores: Jim 77, Zoe 104
# Jane (Rock) vs Peter (Scissors) -> Scores: Jane 83, Peter 91
# Jane (Rock) vs Zoe (Rock) -> Scores: Jane 83, Zoe 104
# Peter (Paper) vs Zoe (Scissors) -> Scores: Peter 91, Zoe 105
#
# Current standings:
# Jim -> Score: 77
# Jane -> Score: 83
# Peter -> Score: 91
# Zoe -> Score: 105
# ==================================================
# Jim (Paper) vs Jane (Rock) -> Scores: Jim 78, Jane 83
# Jim (Rock) vs Peter (Scissors) -> Scores: Jim 79, Peter 91
# Jim (Scissors) vs Zoe (Scissors) -> Scores: Jim 79, Zoe 105
# Jane (Rock) vs Peter (Scissors) -> Scores: Jane 84, Peter 91
# Jane (Paper) vs Zoe (Paper) -> Scores: Jane 84, Zoe 105
# Peter (Rock) vs Zoe (Scissors) -> Scores: Peter 92, Zoe 105
#
# Current standings:
# Jim -> Score: 79
# Jane -> Score: 84
# Peter -> Score: 92
# Zoe -> Score: 105
# ==================================================
# Jim (Paper) vs Jane (Paper) -> Scores: Jim 79, Jane 84
# Jim (Rock) vs Peter (Paper) -> Scores: Jim 79, Peter 93
# Jim (Rock) vs Zoe (Paper) -> Scores: Jim 79, Zoe 106
# Jane (Paper) vs Peter (Rock) -> Scores: Jane 85, Peter 93
# Jane (Rock) vs Zoe (Paper) -> Scores: Jane 85, Zoe 107
# Peter (Rock) vs Zoe (Paper) -> Scores: Peter 93, Zoe 108
#
# Current standings:
# Jim -> Score: 79
# Jane -> Score: 85
# Peter -> Score: 93
# Zoe -> Score: 108
# ==================================================
# Jim (Rock) vs Jane (Rock) -> Scores: Jim 79, Jane 85
# Jim (Scissors) vs Peter (Rock) -> Scores: Jim 79, Peter 94
# Jim (Rock) vs Zoe (Scissors) -> Scores: Jim 80, Zoe 108
# Jane (Paper) vs Peter (Paper) -> Scores: Jane 85, Peter 94
# Jane (Scissors) vs Zoe (Paper) -> Scores: Jane 86, Zoe 108
# Peter (Scissors) vs Zoe (Rock) -> Scores: Peter 94, Zoe 109
#
# Current standings:
# Jim -> Score: 80
# Jane -> Score: 86
# Peter -> Score: 94
# Zoe -> Score: 109
# ==================================================
# Jim (Scissors) vs Jane (Rock) -> Scores: Jim 80, Jane 87
# Jim (Scissors) vs Peter (Paper) -> Scores: Jim 81, Peter 94
# Jim (Paper) vs Zoe (Rock) -> Scores: Jim 82, Zoe 109
# Jane (Rock) vs Peter (Paper) -> Scores: Jane 87, Peter 95
# Jane (Scissors) vs Zoe (Paper) -> Scores: Jane 88, Zoe 109
# Peter (Rock) vs Zoe (Scissors) -> Scores: Peter 96, Zoe 109
#
# Current standings:
# Jim -> Score: 82
# Jane -> Score: 88
# Peter -> Score: 96
# Zoe -> Score: 109
# ==================================================
# Jim (Paper) vs Jane (Scissors) -> Scores: Jim 82, Jane 89
# Jim (Paper) vs Peter (Scissors) -> Scores: Jim 82, Peter 97
# Jim (Scissors) vs Zoe (Paper) -> Scores: Jim 83, Zoe 109
# Jane (Rock) vs Peter (Paper) -> Scores: Jane 89, Peter 98
# Jane (Scissors) vs Zoe (Paper) -> Scores: Jane 90, Zoe 109
# Peter (Scissors) vs Zoe (Rock) -> Scores: Peter 98, Zoe 110
#
# Current standings:
# Jim -> Score: 83
# Jane -> Score: 90
# Peter -> Score: 98
# Zoe -> Score: 110
# ==================================================
# Jim (Paper) vs Jane (Rock) -> Scores: Jim 84, Jane 90
# Jim (Paper) vs Peter (Paper) -> Scores: Jim 84, Peter 98
# Jim (Scissors) vs Zoe (Scissors) -> Scores: Jim 84, Zoe 110
# Jane (Paper) vs Peter (Rock) -> Scores: Jane 91, Peter 98
# Jane (Rock) vs Zoe (Rock) -> Scores: Jane 91, Zoe 110
# Peter (Scissors) vs Zoe (Rock) -> Scores: Peter 98, Zoe 111
#
# Current standings:
# Jim -> Score: 84
# Jane -> Score: 91
# Peter -> Score: 98
# Zoe -> Score: 111
# ==================================================
# Jim (Rock) vs Jane (Scissors) -> Scores: Jim 85, Jane 91
# Jim (Scissors) vs Peter (Scissors) -> Scores: Jim 85, Peter 98
# Jim (Rock) vs Zoe (Paper) -> Scores: Jim 85, Zoe 112
# Jane (Rock) vs Peter (Paper) -> Scores: Jane 91, Peter 99
# Jane (Rock) vs Zoe (Rock) -> Scores: Jane 91, Zoe 112
# Peter (Paper) vs Zoe (Rock) -> Scores: Peter 100, Zoe 112
#
# Current standings:
# Jim -> Score: 85
# Jane -> Score: 91
# Peter -> Score: 100
# Zoe -> Score: 112
# ==================================================
# Jim (Paper) vs Jane (Paper) -> Scores: Jim 85, Jane 91
# Jim (Rock) vs Peter (Paper) -> Scores: Jim 85, Peter 101
# Jim (Rock) vs Zoe (Paper) -> Scores: Jim 85, Zoe 113
# Jane (Scissors) vs Peter (Rock) -> Scores: Jane 91, Peter 102
# Jane (Scissors) vs Zoe (Scissors) -> Scores: Jane 91, Zoe 113
# Peter (Rock) vs Zoe (Scissors) -> Scores: Peter 103, Zoe 113
#
# Current standings:
# Jim -> Score: 85
# Jane -> Score: 91
# Peter -> Score: 103
# Zoe -> Score: 113
# ==================================================
# Jim (Paper) vs Jane (Paper) -> Scores: Jim 85, Jane 91
# Jim (Rock) vs Peter (Rock) -> Scores: Jim 85, Peter 103
# Jim (Paper) vs Zoe (Paper) -> Scores: Jim 85, Zoe 113
# Jane (Rock) vs Peter (Paper) -> Scores: Jane 91, Peter 104
# Jane (Rock) vs Zoe (Paper) -> Scores: Jane 91, Zoe 114
# Peter (Paper) vs Zoe (Rock) -> Scores: Peter 105, Zoe 114
#
# Current standings:
# Jim -> Score: 85
# Jane -> Score: 91
# Peter -> Score: 105
# Zoe -> Score: 114
# ==================================================
# Jim (Rock) vs Jane (Paper) -> Scores: Jim 85, Jane 92
# Jim (Rock) vs Peter (Rock) -> Scores: Jim 85, Peter 105
# Jim (Scissors) vs Zoe (Scissors) -> Scores: Jim 85, Zoe 114
# Jane (Rock) vs Peter (Rock) -> Scores: Jane 92, Peter 105
# Jane (Rock) vs Zoe (Scissors) -> Scores: Jane 93, Zoe 114
# Peter (Rock) vs Zoe (Paper) -> Scores: Peter 105, Zoe 115
#
# Current standings:
# Jim -> Score: 85
# Jane -> Score: 93
# Peter -> Score: 105
# Zoe -> Score: 115
# ==================================================
# Jim (Scissors) vs Jane (Rock) -> Scores: Jim 85, Jane 94
# Jim (Scissors) vs Peter (Rock) -> Scores: Jim 85, Peter 106
# Jim (Paper) vs Zoe (Paper) -> Scores: Jim 85, Zoe 115
# Jane (Scissors) vs Peter (Rock) -> Scores: Jane 94, Peter 107
# Jane (Paper) vs Zoe (Scissors) -> Scores: Jane 94, Zoe 116
# Peter (Rock) vs Zoe (Paper) -> Scores: Peter 107, Zoe 117
#
# Current standings:
# Jim -> Score: 85
# Jane -> Score: 94
# Peter -> Score: 107
# Zoe -> Score: 117
# ==================================================

# %%
# ¿Cómo queda?
society
# Out:
# [{'name': 'Jim', 'score': 85, 'strategy': 'Paper'},
#  {'name': 'Jane', 'score': 94, 'strategy': 'Paper'},
#  {'name': 'Peter', 'score': 107, 'strategy': 'Rock'},
#  {'name': 'Zoe', 'score': 117, 'strategy': 'Paper'}]

# %%
import pandas as pd

# %%
# organizamos en un data frame
socialResults=pd.DataFrame(society)
socialResults
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 # organizamos en un data frame
# ----> 2 socialResults=pd.DataFrame(society)
#       3 socialResults
#
# NameError: name 'pd' is not defined

# %%
# ¿Quien gana?
winnerScore=socialResults.score.max()

socialResults[socialResults.score==winnerScore]
# Out:
#    name  score  strategy
# 1  Jane    104  Scissors

# %% [markdown]
# ## Ejercicio 2: Aplicación para el juego "Piedra, Papel, Tijera, Lagarto, Spock"

# %% [markdown]
# <img src="https://i.imgur.com/DE5mjs4.jpg"/>

# %% [markdown]
# **Qué vence a qué**:
#    - **Piedra (Rock)**:
#      - Aplasta **Tijeras (Scissors)**.
#      - Aplasta **Lagarto (Lizard)**.
#    - **Papel (Paper)**:
#      - Cubre **Piedra (Rock)**.
#      - Refuta **Spock**.
#    - **Tijera (Scissors)**:
#      - Corta **Papel (Paper)**.
#      - Decapita **Lagarto (Lizard)**.
#    - **Lagarto (Lizard)**:
#      - Envenena **Spock**.
#      - Come **Papel (Paper)**.
#    - **Spock**:
#      - Rompe **Tijeras (Scissors)**.
#      - Vaporiza **Piedra (Rock)**.

# %%
# Estrategias disponibles
strategies2 = ['Rock', 'Paper', 'Scissors', 'Lizard', 'Spock']

# %%
# Tabla de todos los resultados posibles (payoff)
payoff = {
    ('Rock', 'Scissors'): (1, 0), ('Scissors', 'Rock'): (0, 1),
    ('Rock', 'Lizard'): (1, 0), ('Lizard', 'Rock'): (0, 1),
    ('Paper', 'Rock'): (1, 0), ('Rock', 'Paper'): (0, 1),
    ('Paper', 'Spock'): (1, 0), ('Spock', 'Paper'): (0, 1),
    ('Scissors', 'Paper'): (1, 0), ('Paper', 'Scissors'): (0, 1),
    ('Scissors', 'Lizard'): (1, 0), ('Lizard', 'Scissors'): (0, 1),
    ('Lizard', 'Spock'): (1, 0), ('Spock', 'Lizard'): (0, 1),
    ('Spock', 'Scissors'): (1, 0), ('Scissors', 'Spock'): (0, 1),
    ('Rock', 'Rock'): (0, 0), ('Paper', 'Paper'): (0, 0),
    ('Scissors', 'Scissors'): (0, 0), ('Lizard', 'Lizard'): (0, 0),
    ('Spock', 'Spock'): (0, 0),
}

# %%
# Inicialización de los jugadores
names = ['rosite', 'aleli', 'ed', 'charles', 'nico', 
         'elenita', 'dani', 'liz', 'tomi', 'jose']
society2 = [{'name': n, 'score': 0, 'strategy': None} for n in names]

# %%
from random import choice

#simplest strategy: choose randomly
choice(strategies2);

# %%
# Simulación de varias rondas
for aRound in range(10): 
    print(f"Round {aRound + 1}")
    for player1, player2 in itertools.combinations(society2, 2):  # Enfrentamientos en pares
        # Cada jugador elige una estrategia
        player1['strategy'] = choice(strategies2)
        player2['strategy'] = choice(strategies2)
        
        # Calcular el resultado
        result = payoff.get((player1['strategy'], player2['strategy']), (0, 0))  # Empate por defecto
        player1['score'] += result[0]
        player2['score'] += result[1]
        
        # Mostrar resultados en vivo
        print(f"{player1['name']} ({player1['strategy']}) vs {player2['name']} ({player2['strategy']}) -> "
              f"Scores: {player1['name']} {player1['score']}, {player2['name']} {player2['score']}")
    print("=" * 50)
# Out:
# Round 1
# rosite (Scissors) vs aleli (Rock) -> Scores: rosite 30, aleli 32
# rosite (Lizard) vs ed (Rock) -> Scores: rosite 30, ed 39
# rosite (Spock) vs charles (Rock) -> Scores: rosite 30, charles 24
# rosite (Scissors) vs nico (Scissors) -> Scores: rosite 30, nico 32
# rosite (Scissors) vs elenita (Scissors) -> Scores: rosite 30, elenita 31
# rosite (Lizard) vs dani (Paper) -> Scores: rosite 30, dani 30
# rosite (Paper) vs liz (Paper) -> Scores: rosite 30, liz 34
# rosite (Rock) vs tomi (Rock) -> Scores: rosite 30, tomi 29
# rosite (Scissors) vs jose (Scissors) -> Scores: rosite 30, jose 27
# aleli (Spock) vs ed (Rock) -> Scores: aleli 32, ed 39
# aleli (Lizard) vs charles (Paper) -> Scores: aleli 32, charles 24
# aleli (Spock) vs nico (Rock) -> Scores: aleli 32, nico 32
# aleli (Paper) vs elenita (Rock) -> Scores: aleli 33, elenita 31
# aleli (Paper) vs dani (Scissors) -> Scores: aleli 33, dani 31
# aleli (Rock) vs liz (Lizard) -> Scores: aleli 34, liz 34
# aleli (Rock) vs tomi (Spock) -> Scores: aleli 34, tomi 29
# aleli (Lizard) vs jose (Rock) -> Scores: aleli 34, jose 28
# ed (Paper) vs charles (Rock) -> Scores: ed 40, charles 24
# ed (Scissors) vs nico (Spock) -> Scores: ed 40, nico 33
# ed (Paper) vs elenita (Scissors) -> Scores: ed 40, elenita 32
# ed (Rock) vs dani (Scissors) -> Scores: ed 41, dani 31
# ed (Rock) vs liz (Scissors) -> Scores: ed 42, liz 34
# ed (Spock) vs tomi (Paper) -> Scores: ed 42, tomi 30
# ed (Paper) vs jose (Paper) -> Scores: ed 42, jose 28
# charles (Scissors) vs nico (Spock) -> Scores: charles 24, nico 34
# charles (Spock) vs elenita (Paper) -> Scores: charles 24, elenita 33
# charles (Spock) vs dani (Lizard) -> Scores: charles 24, dani 32
# charles (Scissors) vs liz (Rock) -> Scores: charles 24, liz 35
# charles (Scissors) vs tomi (Lizard) -> Scores: charles 25, tomi 30
# charles (Rock) vs jose (Lizard) -> Scores: charles 26, jose 28
# nico (Rock) vs elenita (Scissors) -> Scores: nico 35, elenita 33
# nico (Scissors) vs dani (Paper) -> Scores: nico 36, dani 32
# nico (Scissors) vs liz (Spock) -> Scores: nico 36, liz 36
# nico (Rock) vs tomi (Rock) -> Scores: nico 36, tomi 30
# nico (Spock) vs jose (Rock) -> Scores: nico 36, jose 28
# elenita (Paper) vs dani (Rock) -> Scores: elenita 34, dani 32
# elenita (Spock) vs liz (Rock) -> Scores: elenita 34, liz 36
# elenita (Lizard) vs tomi (Rock) -> Scores: elenita 34, tomi 31
# elenita (Paper) vs jose (Rock) -> Scores: elenita 35, jose 28
# dani (Rock) vs liz (Spock) -> Scores: dani 32, liz 36
# dani (Lizard) vs tomi (Paper) -> Scores: dani 32, tomi 31
# dani (Lizard) vs jose (Scissors) -> Scores: dani 32, jose 29
# liz (Spock) vs tomi (Spock) -> Scores: liz 36, tomi 31
# liz (Spock) vs jose (Rock) -> Scores: liz 36, jose 29
# tomi (Lizard) vs jose (Scissors) -> Scores: tomi 31, jose 30
# ==================================================
# Round 2
# rosite (Rock) vs aleli (Paper) -> Scores: rosite 30, aleli 35
# rosite (Lizard) vs ed (Lizard) -> Scores: rosite 30, ed 42
# rosite (Scissors) vs charles (Rock) -> Scores: rosite 30, charles 27
# rosite (Lizard) vs nico (Lizard) -> Scores: rosite 30, nico 36
# rosite (Scissors) vs elenita (Paper) -> Scores: rosite 31, elenita 35
# rosite (Spock) vs dani (Scissors) -> Scores: rosite 32, dani 32
# rosite (Spock) vs liz (Rock) -> Scores: rosite 32, liz 36
# rosite (Lizard) vs tomi (Scissors) -> Scores: rosite 32, tomi 32
# rosite (Scissors) vs jose (Lizard) -> Scores: rosite 33, jose 30
# aleli (Paper) vs ed (Paper) -> Scores: aleli 35, ed 42
# aleli (Spock) vs charles (Spock) -> Scores: aleli 35, charles 27
# aleli (Scissors) vs nico (Lizard) -> Scores: aleli 36, nico 36
# aleli (Lizard) vs elenita (Paper) -> Scores: aleli 36, elenita 35
# aleli (Paper) vs dani (Scissors) -> Scores: aleli 36, dani 33
# aleli (Spock) vs liz (Rock) -> Scores: aleli 36, liz 36
# aleli (Scissors) vs tomi (Lizard) -> Scores: aleli 37, tomi 32
# aleli (Scissors) vs jose (Rock) -> Scores: aleli 37, jose 31
# ed (Lizard) vs charles (Spock) -> Scores: ed 43, charles 27
# ed (Spock) vs nico (Spock) -> Scores: ed 43, nico 36
# ed (Spock) vs elenita (Rock) -> Scores: ed 43, elenita 35
# ed (Lizard) vs dani (Spock) -> Scores: ed 44, dani 33
# ed (Scissors) vs liz (Lizard) -> Scores: ed 45, liz 36
# ed (Lizard) vs tomi (Scissors) -> Scores: ed 45, tomi 33
# ed (Lizard) vs jose (Rock) -> Scores: ed 45, jose 32
# charles (Paper) vs nico (Lizard) -> Scores: charles 27, nico 36
# charles (Paper) vs elenita (Spock) -> Scores: charles 28, elenita 35
# charles (Spock) vs dani (Paper) -> Scores: charles 28, dani 34
# charles (Lizard) vs liz (Lizard) -> Scores: charles 28, liz 36
# charles (Scissors) vs tomi (Scissors) -> Scores: charles 28, tomi 33
# charles (Spock) vs jose (Scissors) -> Scores: charles 29, jose 32
# nico (Lizard) vs elenita (Paper) -> Scores: nico 36, elenita 35
# nico (Rock) vs dani (Lizard) -> Scores: nico 37, dani 34
# nico (Lizard) vs liz (Spock) -> Scores: nico 38, liz 36
# nico (Paper) vs tomi (Paper) -> Scores: nico 38, tomi 33
# nico (Rock) vs jose (Spock) -> Scores: nico 38, jose 32
# elenita (Spock) vs dani (Paper) -> Scores: elenita 35, dani 35
# elenita (Lizard) vs liz (Paper) -> Scores: elenita 35, liz 36
# elenita (Lizard) vs tomi (Scissors) -> Scores: elenita 35, tomi 34
# elenita (Paper) vs jose (Spock) -> Scores: elenita 36, jose 32
# dani (Scissors) vs liz (Scissors) -> Scores: dani 35, liz 36
# dani (Scissors) vs tomi (Paper) -> Scores: dani 36, tomi 34
# dani (Paper) vs jose (Scissors) -> Scores: dani 36, jose 33
# liz (Scissors) vs tomi (Lizard) -> Scores: liz 37, tomi 34
# liz (Rock) vs jose (Paper) -> Scores: liz 37, jose 34
# tomi (Scissors) vs jose (Spock) -> Scores: tomi 34, jose 35
# ==================================================
# Round 3
# rosite (Paper) vs aleli (Rock) -> Scores: rosite 34, aleli 37
# rosite (Scissors) vs ed (Rock) -> Scores: rosite 34, ed 46
# rosite (Scissors) vs charles (Rock) -> Scores: rosite 34, charles 30
# rosite (Lizard) vs nico (Paper) -> Scores: rosite 34, nico 38
# rosite (Paper) vs elenita (Spock) -> Scores: rosite 35, elenita 36
# rosite (Scissors) vs dani (Spock) -> Scores: rosite 35, dani 37
# rosite (Paper) vs liz (Scissors) -> Scores: rosite 35, liz 38
# rosite (Rock) vs tomi (Lizard) -> Scores: rosite 36, tomi 34
# rosite (Spock) vs jose (Paper) -> Scores: rosite 36, jose 36
# aleli (Rock) vs ed (Spock) -> Scores: aleli 37, ed 46
# aleli (Spock) vs charles (Rock) -> Scores: aleli 37, charles 30
# aleli (Rock) vs nico (Paper) -> Scores: aleli 37, nico 39
# aleli (Spock) vs elenita (Rock) -> Scores: aleli 37, elenita 36
# aleli (Lizard) vs dani (Spock) -> Scores: aleli 38, dani 37
# aleli (Rock) vs liz (Scissors) -> Scores: aleli 39, liz 38
# aleli (Lizard) vs tomi (Rock) -> Scores: aleli 39, tomi 35
# aleli (Paper) vs jose (Rock) -> Scores: aleli 40, jose 36
# ed (Lizard) vs charles (Paper) -> Scores: ed 46, charles 30
# ed (Spock) vs nico (Spock) -> Scores: ed 46, nico 39
# ed (Rock) vs elenita (Lizard) -> Scores: ed 47, elenita 36
# ed (Scissors) vs dani (Lizard) -> Scores: ed 48, dani 37
# ed (Spock) vs liz (Scissors) -> Scores: ed 49, liz 38
# ed (Paper) vs tomi (Rock) -> Scores: ed 50, tomi 35
# ed (Lizard) vs jose (Spock) -> Scores: ed 51, jose 36
# charles (Rock) vs nico (Lizard) -> Scores: charles 31, nico 39
# charles (Spock) vs elenita (Rock) -> Scores: charles 31, elenita 36
# charles (Rock) vs dani (Rock) -> Scores: charles 31, dani 37
# charles (Rock) vs liz (Spock) -> Scores: charles 31, liz 38
# charles (Paper) vs tomi (Paper) -> Scores: charles 31, tomi 35
# charles (Rock) vs jose (Paper) -> Scores: charles 31, jose 37
# nico (Paper) vs elenita (Rock) -> Scores: nico 40, elenita 36
# nico (Spock) vs dani (Paper) -> Scores: nico 40, dani 38
# nico (Scissors) vs liz (Lizard) -> Scores: nico 41, liz 38
# nico (Spock) vs tomi (Scissors) -> Scores: nico 42, tomi 35
# nico (Scissors) vs jose (Lizard) -> Scores: nico 43, jose 37
# elenita (Lizard) vs dani (Spock) -> Scores: elenita 37, dani 38
# elenita (Spock) vs liz (Lizard) -> Scores: elenita 37, liz 39
# elenita (Rock) vs tomi (Paper) -> Scores: elenita 37, tomi 36
# elenita (Spock) vs jose (Scissors) -> Scores: elenita 38, jose 37
# dani (Lizard) vs liz (Rock) -> Scores: dani 38, liz 40
# dani (Lizard) vs tomi (Spock) -> Scores: dani 39, tomi 36
# dani (Spock) vs jose (Spock) -> Scores: dani 39, jose 37
# liz (Spock) vs tomi (Lizard) -> Scores: liz 40, tomi 37
# liz (Spock) vs jose (Scissors) -> Scores: liz 41, jose 37
# tomi (Rock) vs jose (Scissors) -> Scores: tomi 38, jose 37
# ==================================================
# Round 4
# rosite (Spock) vs aleli (Lizard) -> Scores: rosite 36, aleli 41
# rosite (Scissors) vs ed (Rock) -> Scores: rosite 36, ed 52
# rosite (Scissors) vs charles (Spock) -> Scores: rosite 36, charles 32
# rosite (Paper) vs nico (Spock) -> Scores: rosite 37, nico 43
# rosite (Lizard) vs elenita (Scissors) -> Scores: rosite 37, elenita 39
# rosite (Lizard) vs dani (Spock) -> Scores: rosite 38, dani 39
# rosite (Scissors) vs liz (Scissors) -> Scores: rosite 38, liz 41
# rosite (Paper) vs tomi (Lizard) -> Scores: rosite 38, tomi 38
# rosite (Rock) vs jose (Rock) -> Scores: rosite 38, jose 37
# aleli (Paper) vs ed (Rock) -> Scores: aleli 42, ed 52
# aleli (Spock) vs charles (Paper) -> Scores: aleli 42, charles 33
# aleli (Lizard) vs nico (Spock) -> Scores: aleli 43, nico 43
# aleli (Spock) vs elenita (Spock) -> Scores: aleli 43, elenita 39
# aleli (Scissors) vs dani (Spock) -> Scores: aleli 43, dani 40
# aleli (Paper) vs liz (Paper) -> Scores: aleli 43, liz 41
# aleli (Spock) vs tomi (Rock) -> Scores: aleli 43, tomi 38
# aleli (Paper) vs jose (Spock) -> Scores: aleli 44, jose 37
# ed (Spock) vs charles (Spock) -> Scores: ed 52, charles 33
# ed (Lizard) vs nico (Spock) -> Scores: ed 53, nico 43
# ed (Spock) vs elenita (Spock) -> Scores: ed 53, elenita 39
# ed (Lizard) vs dani (Rock) -> Scores: ed 53, dani 41
# ed (Spock) vs liz (Scissors) -> Scores: ed 54, liz 41
# ed (Scissors) vs tomi (Scissors) -> Scores: ed 54, tomi 38
# ed (Scissors) vs jose (Paper) -> Scores: ed 55, jose 37
# charles (Lizard) vs nico (Scissors) -> Scores: charles 33, nico 44
# charles (Paper) vs elenita (Lizard) -> Scores: charles 33, elenita 39
# charles (Rock) vs dani (Paper) -> Scores: charles 33, dani 42
# charles (Rock) vs liz (Lizard) -> Scores: charles 34, liz 41
# charles (Scissors) vs tomi (Paper) -> Scores: charles 35, tomi 38
# charles (Rock) vs jose (Scissors) -> Scores: charles 36, jose 37
# nico (Paper) vs elenita (Scissors) -> Scores: nico 44, elenita 40
# nico (Scissors) vs dani (Paper) -> Scores: nico 45, dani 42
# nico (Paper) vs liz (Rock) -> Scores: nico 46, liz 41
# nico (Spock) vs tomi (Rock) -> Scores: nico 46, tomi 38
# nico (Lizard) vs jose (Lizard) -> Scores: nico 46, jose 37
# elenita (Paper) vs dani (Paper) -> Scores: elenita 40, dani 42
# elenita (Paper) vs liz (Rock) -> Scores: elenita 41, liz 41
# elenita (Spock) vs tomi (Rock) -> Scores: elenita 41, tomi 38
# elenita (Lizard) vs jose (Lizard) -> Scores: elenita 41, jose 37
# dani (Lizard) vs liz (Scissors) -> Scores: dani 42, liz 42
# dani (Spock) vs tomi (Paper) -> Scores: dani 42, tomi 39
# dani (Rock) vs jose (Lizard) -> Scores: dani 43, jose 37
# liz (Lizard) vs tomi (Scissors) -> Scores: liz 42, tomi 40
# liz (Lizard) vs jose (Lizard) -> Scores: liz 42, jose 37
# tomi (Lizard) vs jose (Rock) -> Scores: tomi 40, jose 38
# ==================================================
# Round 5
# rosite (Spock) vs aleli (Spock) -> Scores: rosite 38, aleli 44
# rosite (Lizard) vs ed (Rock) -> Scores: rosite 38, ed 56
# rosite (Paper) vs charles (Spock) -> Scores: rosite 39, charles 36
# rosite (Rock) vs nico (Paper) -> Scores: rosite 39, nico 47
# rosite (Scissors) vs elenita (Scissors) -> Scores: rosite 39, elenita 41
# rosite (Spock) vs dani (Paper) -> Scores: rosite 39, dani 44
# rosite (Paper) vs liz (Paper) -> Scores: rosite 39, liz 42
# rosite (Lizard) vs tomi (Paper) -> Scores: rosite 39, tomi 40
# rosite (Paper) vs jose (Paper) -> Scores: rosite 39, jose 38
# aleli (Spock) vs ed (Lizard) -> Scores: aleli 44, ed 57
# aleli (Lizard) vs charles (Spock) -> Scores: aleli 45, charles 36
# aleli (Paper) vs nico (Lizard) -> Scores: aleli 45, nico 47
# aleli (Paper) vs elenita (Scissors) -> Scores: aleli 45, elenita 42
# aleli (Rock) vs dani (Rock) -> Scores: aleli 45, dani 44
# aleli (Lizard) vs liz (Paper) -> Scores: aleli 45, liz 42
# aleli (Paper) vs tomi (Rock) -> Scores: aleli 46, tomi 40
# aleli (Scissors) vs jose (Spock) -> Scores: aleli 46, jose 39
# ed (Paper) vs charles (Paper) -> Scores: ed 57, charles 36
# ed (Lizard) vs nico (Paper) -> Scores: ed 57, nico 47
# ed (Scissors) vs elenita (Spock) -> Scores: ed 57, elenita 43
# ed (Lizard) vs dani (Lizard) -> Scores: ed 57, dani 44
# ed (Rock) vs liz (Scissors) -> Scores: ed 58, liz 42
# ed (Spock) vs tomi (Scissors) -> Scores: ed 59, tomi 40
# ed (Scissors) vs jose (Paper) -> Scores: ed 60, jose 39
# charles (Spock) vs nico (Rock) -> Scores: charles 36, nico 47
# charles (Spock) vs elenita (Scissors) -> Scores: charles 37, elenita 43
# charles (Rock) vs dani (Spock) -> Scores: charles 37, dani 44
# charles (Rock) vs liz (Scissors) -> Scores: charles 38, liz 42
# charles (Rock) vs tomi (Scissors) -> Scores: charles 39, tomi 40
# charles (Spock) vs jose (Lizard) -> Scores: charles 39, jose 40
# nico (Rock) vs elenita (Scissors) -> Scores: nico 48, elenita 43
# nico (Spock) vs dani (Rock) -> Scores: nico 48, dani 44
# nico (Paper) vs liz (Lizard) -> Scores: nico 48, liz 42
# nico (Scissors) vs tomi (Rock) -> Scores: nico 48, tomi 41
# nico (Paper) vs jose (Lizard) -> Scores: nico 48, jose 40
# elenita (Paper) vs dani (Lizard) -> Scores: elenita 43, dani 44
# elenita (Scissors) vs liz (Lizard) -> Scores: elenita 44, liz 42
# elenita (Rock) vs tomi (Scissors) -> Scores: elenita 45, tomi 41
# elenita (Lizard) vs jose (Spock) -> Scores: elenita 46, jose 40
# dani (Lizard) vs liz (Lizard) -> Scores: dani 44, liz 42
# dani (Rock) vs tomi (Paper) -> Scores: dani 44, tomi 42
# dani (Paper) vs jose (Spock) -> Scores: dani 45, jose 40
# liz (Spock) vs tomi (Scissors) -> Scores: liz 43, tomi 42
# liz (Spock) vs jose (Scissors) -> Scores: liz 44, jose 40
# tomi (Rock) vs jose (Paper) -> Scores: tomi 42, jose 41
# ==================================================
# Round 6
# rosite (Spock) vs aleli (Scissors) -> Scores: rosite 40, aleli 46
# rosite (Scissors) vs ed (Scissors) -> Scores: rosite 40, ed 60
# rosite (Paper) vs charles (Spock) -> Scores: rosite 41, charles 39
# rosite (Paper) vs nico (Scissors) -> Scores: rosite 41, nico 49
# rosite (Spock) vs elenita (Scissors) -> Scores: rosite 42, elenita 46
# rosite (Scissors) vs dani (Paper) -> Scores: rosite 43, dani 45
# rosite (Scissors) vs liz (Paper) -> Scores: rosite 44, liz 44
# rosite (Scissors) vs tomi (Paper) -> Scores: rosite 45, tomi 42
# rosite (Spock) vs jose (Rock) -> Scores: rosite 45, jose 41
# aleli (Spock) vs ed (Spock) -> Scores: aleli 46, ed 60
# aleli (Paper) vs charles (Spock) -> Scores: aleli 47, charles 39
# aleli (Paper) vs nico (Spock) -> Scores: aleli 48, nico 49
# aleli (Lizard) vs elenita (Spock) -> Scores: aleli 49, elenita 46
# aleli (Scissors) vs dani (Rock) -> Scores: aleli 49, dani 46
# aleli (Spock) vs liz (Scissors) -> Scores: aleli 50, liz 44
# aleli (Paper) vs tomi (Rock) -> Scores: aleli 51, tomi 42
# aleli (Spock) vs jose (Paper) -> Scores: aleli 51, jose 42
# ed (Spock) vs charles (Spock) -> Scores: ed 60, charles 39
# ed (Lizard) vs nico (Rock) -> Scores: ed 60, nico 50
# ed (Rock) vs elenita (Paper) -> Scores: ed 60, elenita 47
# ed (Rock) vs dani (Lizard) -> Scores: ed 61, dani 46
# ed (Lizard) vs liz (Rock) -> Scores: ed 61, liz 45
# ed (Scissors) vs tomi (Spock) -> Scores: ed 61, tomi 43
# ed (Rock) vs jose (Scissors) -> Scores: ed 62, jose 42
# charles (Paper) vs nico (Lizard) -> Scores: charles 39, nico 50
# charles (Rock) vs elenita (Rock) -> Scores: charles 39, elenita 47
# charles (Spock) vs dani (Paper) -> Scores: charles 39, dani 47
# charles (Rock) vs liz (Paper) -> Scores: charles 39, liz 46
# charles (Paper) vs tomi (Lizard) -> Scores: charles 39, tomi 43
# charles (Scissors) vs jose (Scissors) -> Scores: charles 39, jose 42
# nico (Spock) vs elenita (Lizard) -> Scores: nico 50, elenita 48
# nico (Rock) vs dani (Lizard) -> Scores: nico 51, dani 47
# nico (Spock) vs liz (Rock) -> Scores: nico 51, liz 46
# nico (Scissors) vs tomi (Spock) -> Scores: nico 51, tomi 44
# nico (Lizard) vs jose (Spock) -> Scores: nico 52, jose 42
# elenita (Rock) vs dani (Lizard) -> Scores: elenita 49, dani 47
# elenita (Rock) vs liz (Lizard) -> Scores: elenita 50, liz 46
# elenita (Scissors) vs tomi (Paper) -> Scores: elenita 51, tomi 44
# elenita (Scissors) vs jose (Spock) -> Scores: elenita 51, jose 43
# dani (Paper) vs liz (Lizard) -> Scores: dani 47, liz 46
# dani (Paper) vs tomi (Spock) -> Scores: dani 48, tomi 44
# dani (Rock) vs jose (Spock) -> Scores: dani 48, jose 43
# liz (Scissors) vs tomi (Spock) -> Scores: liz 46, tomi 45
# liz (Spock) vs jose (Scissors) -> Scores: liz 47, jose 43
# tomi (Rock) vs jose (Spock) -> Scores: tomi 45, jose 43
# ==================================================
# Round 7
# rosite (Lizard) vs aleli (Paper) -> Scores: rosite 45, aleli 51
# rosite (Paper) vs ed (Paper) -> Scores: rosite 45, ed 62
# rosite (Rock) vs charles (Lizard) -> Scores: rosite 46, charles 39
# rosite (Scissors) vs nico (Rock) -> Scores: rosite 46, nico 53
# rosite (Spock) vs elenita (Lizard) -> Scores: rosite 46, elenita 52
# rosite (Rock) vs dani (Rock) -> Scores: rosite 46, dani 48
# rosite (Rock) vs liz (Lizard) -> Scores: rosite 47, liz 47
# rosite (Paper) vs tomi (Lizard) -> Scores: rosite 47, tomi 45
# rosite (Scissors) vs jose (Scissors) -> Scores: rosite 47, jose 43
# aleli (Scissors) vs ed (Spock) -> Scores: aleli 51, ed 63
# aleli (Lizard) vs charles (Rock) -> Scores: aleli 51, charles 40
# aleli (Scissors) vs nico (Paper) -> Scores: aleli 52, nico 53
# aleli (Lizard) vs elenita (Spock) -> Scores: aleli 53, elenita 52
# aleli (Rock) vs dani (Paper) -> Scores: aleli 53, dani 49
# aleli (Spock) vs liz (Paper) -> Scores: aleli 53, liz 48
# aleli (Lizard) vs tomi (Scissors) -> Scores: aleli 53, tomi 46
# aleli (Rock) vs jose (Scissors) -> Scores: aleli 54, jose 43
# ed (Lizard) vs charles (Spock) -> Scores: ed 64, charles 40
# ed (Paper) vs nico (Scissors) -> Scores: ed 64, nico 54
# ed (Lizard) vs elenita (Paper) -> Scores: ed 64, elenita 52
# ed (Rock) vs dani (Lizard) -> Scores: ed 65, dani 49
# ed (Spock) vs liz (Spock) -> Scores: ed 65, liz 48
# ed (Paper) vs tomi (Spock) -> Scores: ed 66, tomi 46
# ed (Rock) vs jose (Lizard) -> Scores: ed 67, jose 43
# charles (Paper) vs nico (Rock) -> Scores: charles 41, nico 54
# charles (Spock) vs elenita (Spock) -> Scores: charles 41, elenita 52
# charles (Lizard) vs dani (Spock) -> Scores: charles 42, dani 49
# charles (Rock) vs liz (Scissors) -> Scores: charles 43, liz 48
# charles (Paper) vs tomi (Rock) -> Scores: charles 44, tomi 46
# charles (Spock) vs jose (Spock) -> Scores: charles 44, jose 43
# nico (Scissors) vs elenita (Rock) -> Scores: nico 54, elenita 53
# nico (Spock) vs dani (Scissors) -> Scores: nico 55, dani 49
# nico (Rock) vs liz (Scissors) -> Scores: nico 56, liz 48
# nico (Rock) vs tomi (Scissors) -> Scores: nico 57, tomi 46
# nico (Spock) vs jose (Paper) -> Scores: nico 57, jose 44
# elenita (Paper) vs dani (Paper) -> Scores: elenita 53, dani 49
# elenita (Scissors) vs liz (Lizard) -> Scores: elenita 54, liz 48
# elenita (Paper) vs tomi (Spock) -> Scores: elenita 55, tomi 46
# elenita (Spock) vs jose (Scissors) -> Scores: elenita 56, jose 44
# dani (Paper) vs liz (Spock) -> Scores: dani 50, liz 48
# dani (Paper) vs tomi (Lizard) -> Scores: dani 50, tomi 46
# dani (Lizard) vs jose (Spock) -> Scores: dani 51, jose 44
# liz (Lizard) vs tomi (Lizard) -> Scores: liz 48, tomi 46
# liz (Scissors) vs jose (Paper) -> Scores: liz 49, jose 44
# tomi (Spock) vs jose (Rock) -> Scores: tomi 46, jose 44
# ==================================================
# Round 8
# rosite (Lizard) vs aleli (Rock) -> Scores: rosite 47, aleli 55
# rosite (Lizard) vs ed (Paper) -> Scores: rosite 47, ed 67
# rosite (Scissors) vs charles (Spock) -> Scores: rosite 47, charles 45
# rosite (Rock) vs nico (Lizard) -> Scores: rosite 48, nico 57
# rosite (Scissors) vs elenita (Spock) -> Scores: rosite 48, elenita 57
# rosite (Rock) vs dani (Scissors) -> Scores: rosite 49, dani 51
# rosite (Spock) vs liz (Spock) -> Scores: rosite 49, liz 49
# rosite (Spock) vs tomi (Lizard) -> Scores: rosite 49, tomi 47
# rosite (Spock) vs jose (Scissors) -> Scores: rosite 50, jose 44
# aleli (Spock) vs ed (Lizard) -> Scores: aleli 55, ed 68
# aleli (Scissors) vs charles (Scissors) -> Scores: aleli 55, charles 45
# aleli (Scissors) vs nico (Spock) -> Scores: aleli 55, nico 58
# aleli (Spock) vs elenita (Spock) -> Scores: aleli 55, elenita 57
# aleli (Rock) vs dani (Lizard) -> Scores: aleli 56, dani 51
# aleli (Scissors) vs liz (Paper) -> Scores: aleli 57, liz 49
# aleli (Spock) vs tomi (Rock) -> Scores: aleli 57, tomi 47
# aleli (Spock) vs jose (Lizard) -> Scores: aleli 57, jose 45
# ed (Paper) vs charles (Paper) -> Scores: ed 68, charles 45
# ed (Rock) vs nico (Paper) -> Scores: ed 68, nico 59
# ed (Lizard) vs elenita (Paper) -> Scores: ed 68, elenita 57
# ed (Rock) vs dani (Rock) -> Scores: ed 68, dani 51
# ed (Paper) vs liz (Spock) -> Scores: ed 69, liz 49
# ed (Paper) vs tomi (Lizard) -> Scores: ed 69, tomi 47
# ed (Lizard) vs jose (Paper) -> Scores: ed 69, jose 45
# charles (Rock) vs nico (Spock) -> Scores: charles 45, nico 59
# charles (Lizard) vs elenita (Rock) -> Scores: charles 45, elenita 58
# charles (Scissors) vs dani (Scissors) -> Scores: charles 45, dani 51
# charles (Rock) vs liz (Scissors) -> Scores: charles 46, liz 49
# charles (Spock) vs tomi (Rock) -> Scores: charles 46, tomi 47
# charles (Rock) vs jose (Lizard) -> Scores: charles 47, jose 45
# nico (Lizard) vs elenita (Scissors) -> Scores: nico 59, elenita 59
# nico (Scissors) vs dani (Scissors) -> Scores: nico 59, dani 51
# nico (Scissors) vs liz (Rock) -> Scores: nico 59, liz 50
# nico (Scissors) vs tomi (Spock) -> Scores: nico 59, tomi 48
# nico (Lizard) vs jose (Spock) -> Scores: nico 60, jose 45
# elenita (Scissors) vs dani (Lizard) -> Scores: elenita 60, dani 51
# elenita (Rock) vs liz (Spock) -> Scores: elenita 60, liz 50
# elenita (Spock) vs tomi (Paper) -> Scores: elenita 60, tomi 49
# elenita (Scissors) vs jose (Scissors) -> Scores: elenita 60, jose 45
# dani (Spock) vs liz (Rock) -> Scores: dani 51, liz 50
# dani (Spock) vs tomi (Spock) -> Scores: dani 51, tomi 49
# dani (Rock) vs jose (Paper) -> Scores: dani 51, jose 46
# liz (Rock) vs tomi (Paper) -> Scores: liz 50, tomi 50
# liz (Scissors) vs jose (Paper) -> Scores: liz 51, jose 46
# tomi (Rock) vs jose (Rock) -> Scores: tomi 50, jose 46
# ==================================================
# Round 9
# rosite (Lizard) vs aleli (Rock) -> Scores: rosite 50, aleli 58
# rosite (Paper) vs ed (Rock) -> Scores: rosite 51, ed 69
# rosite (Paper) vs charles (Paper) -> Scores: rosite 51, charles 47
# rosite (Paper) vs nico (Paper) -> Scores: rosite 51, nico 60
# rosite (Lizard) vs elenita (Scissors) -> Scores: rosite 51, elenita 61
# rosite (Rock) vs dani (Lizard) -> Scores: rosite 52, dani 51
# rosite (Lizard) vs liz (Spock) -> Scores: rosite 53, liz 51
# rosite (Paper) vs tomi (Scissors) -> Scores: rosite 53, tomi 51
# rosite (Paper) vs jose (Spock) -> Scores: rosite 54, jose 46
# aleli (Rock) vs ed (Lizard) -> Scores: aleli 59, ed 69
# aleli (Rock) vs charles (Spock) -> Scores: aleli 59, charles 47
# aleli (Spock) vs nico (Lizard) -> Scores: aleli 59, nico 61
# aleli (Scissors) vs elenita (Scissors) -> Scores: aleli 59, elenita 61
# aleli (Rock) vs dani (Rock) -> Scores: aleli 59, dani 51
# aleli (Rock) vs liz (Rock) -> Scores: aleli 59, liz 51
# aleli (Spock) vs tomi (Spock) -> Scores: aleli 59, tomi 51
# aleli (Paper) vs jose (Lizard) -> Scores: aleli 59, jose 46
# ed (Rock) vs charles (Paper) -> Scores: ed 69, charles 48
# ed (Scissors) vs nico (Scissors) -> Scores: ed 69, nico 61
# ed (Rock) vs elenita (Paper) -> Scores: ed 69, elenita 62
# ed (Paper) vs dani (Scissors) -> Scores: ed 69, dani 52
# ed (Spock) vs liz (Paper) -> Scores: ed 69, liz 52
# ed (Rock) vs tomi (Spock) -> Scores: ed 69, tomi 51
# ed (Lizard) vs jose (Spock) -> Scores: ed 70, jose 46
# charles (Lizard) vs nico (Scissors) -> Scores: charles 48, nico 62
# charles (Rock) vs elenita (Scissors) -> Scores: charles 49, elenita 62
# charles (Scissors) vs dani (Rock) -> Scores: charles 49, dani 53
# charles (Spock) vs liz (Paper) -> Scores: charles 49, liz 53
# charles (Paper) vs tomi (Scissors) -> Scores: charles 49, tomi 52
# charles (Paper) vs jose (Spock) -> Scores: charles 50, jose 46
# nico (Rock) vs elenita (Scissors) -> Scores: nico 63, elenita 62
# nico (Spock) vs dani (Rock) -> Scores: nico 63, dani 53
# nico (Rock) vs liz (Spock) -> Scores: nico 63, liz 53
# nico (Paper) vs tomi (Lizard) -> Scores: nico 63, tomi 52
# nico (Scissors) vs jose (Scissors) -> Scores: nico 63, jose 46
# elenita (Scissors) vs dani (Scissors) -> Scores: elenita 62, dani 53
# elenita (Spock) vs liz (Rock) -> Scores: elenita 62, liz 53
# elenita (Lizard) vs tomi (Rock) -> Scores: elenita 62, tomi 53
# elenita (Paper) vs jose (Lizard) -> Scores: elenita 62, jose 46
# dani (Scissors) vs liz (Rock) -> Scores: dani 53, liz 54
# dani (Lizard) vs tomi (Rock) -> Scores: dani 53, tomi 54
# dani (Lizard) vs jose (Lizard) -> Scores: dani 53, jose 46
# liz (Rock) vs tomi (Spock) -> Scores: liz 54, tomi 54
# liz (Spock) vs jose (Spock) -> Scores: liz 54, jose 46
# tomi (Scissors) vs jose (Paper) -> Scores: tomi 55, jose 46
# ==================================================
# Round 10
# rosite (Spock) vs aleli (Scissors) -> Scores: rosite 55, aleli 59
# rosite (Rock) vs ed (Lizard) -> Scores: rosite 56, ed 70
# rosite (Paper) vs charles (Spock) -> Scores: rosite 57, charles 50
# rosite (Scissors) vs nico (Rock) -> Scores: rosite 57, nico 64
# rosite (Spock) vs elenita (Rock) -> Scores: rosite 57, elenita 62
# rosite (Lizard) vs dani (Paper) -> Scores: rosite 57, dani 53
# rosite (Paper) vs liz (Paper) -> Scores: rosite 57, liz 54
# rosite (Spock) vs tomi (Rock) -> Scores: rosite 57, tomi 55
# rosite (Spock) vs jose (Lizard) -> Scores: rosite 57, jose 47
# aleli (Spock) vs ed (Paper) -> Scores: aleli 59, ed 71
# aleli (Spock) vs charles (Paper) -> Scores: aleli 59, charles 51
# aleli (Rock) vs nico (Scissors) -> Scores: aleli 60, nico 64
# aleli (Rock) vs elenita (Lizard) -> Scores: aleli 61, elenita 62
# aleli (Scissors) vs dani (Spock) -> Scores: aleli 61, dani 54
# aleli (Rock) vs liz (Spock) -> Scores: aleli 61, liz 54
# aleli (Spock) vs tomi (Scissors) -> Scores: aleli 62, tomi 55
# aleli (Scissors) vs jose (Spock) -> Scores: aleli 62, jose 48
# ed (Spock) vs charles (Scissors) -> Scores: ed 72, charles 51
# ed (Spock) vs nico (Paper) -> Scores: ed 72, nico 65
# ed (Spock) vs elenita (Spock) -> Scores: ed 72, elenita 62
# ed (Lizard) vs dani (Scissors) -> Scores: ed 72, dani 55
# ed (Scissors) vs liz (Spock) -> Scores: ed 72, liz 55
# ed (Scissors) vs tomi (Lizard) -> Scores: ed 73, tomi 55
# ed (Scissors) vs jose (Spock) -> Scores: ed 73, jose 49
# charles (Lizard) vs nico (Spock) -> Scores: charles 52, nico 65
# charles (Spock) vs elenita (Rock) -> Scores: charles 52, elenita 62
# charles (Paper) vs dani (Rock) -> Scores: charles 53, dani 55
# charles (Spock) vs liz (Lizard) -> Scores: charles 53, liz 56
# charles (Scissors) vs tomi (Scissors) -> Scores: charles 53, tomi 55
# charles (Lizard) vs jose (Paper) -> Scores: charles 53, jose 49
# nico (Rock) vs elenita (Rock) -> Scores: nico 65, elenita 62
# nico (Lizard) vs dani (Scissors) -> Scores: nico 65, dani 56
# nico (Scissors) vs liz (Spock) -> Scores: nico 65, liz 57
# nico (Paper) vs tomi (Rock) -> Scores: nico 66, tomi 55
# nico (Scissors) vs jose (Rock) -> Scores: nico 66, jose 50
# elenita (Scissors) vs dani (Lizard) -> Scores: elenita 63, dani 56
# elenita (Spock) vs liz (Rock) -> Scores: elenita 63, liz 57
# elenita (Rock) vs tomi (Paper) -> Scores: elenita 63, tomi 56
# elenita (Paper) vs jose (Paper) -> Scores: elenita 63, jose 50
# dani (Lizard) vs liz (Spock) -> Scores: dani 57, liz 57
# dani (Paper) vs tomi (Lizard) -> Scores: dani 57, tomi 56
# dani (Rock) vs jose (Spock) -> Scores: dani 57, jose 50
# liz (Rock) vs tomi (Lizard) -> Scores: liz 58, tomi 56
# liz (Spock) vs jose (Lizard) -> Scores: liz 58, jose 51
# tomi (Lizard) vs jose (Paper) -> Scores: tomi 56, jose 51
# ==================================================

# %%
# organizamos en un data frame
socialResults2=pd.DataFrame(society2)
socialResults2
# Out:
#       name  score  strategy
# 0   rosite     57     Spock
# 1    aleli     62  Scissors
# 2       ed     73  Scissors
# 3  charles     53    Lizard
# 4     nico     66  Scissors
# 5  elenita     63     Paper
# 6     dani     57      Rock
# 7      liz     58     Spock
# 8     tomi     56    Lizard
# 9     jose     51     Paper

# %%
# ¿Quien gana?
winnerScore2=socialResults2.score.max()

socialResults2[socialResults2.score==winnerScore2]
# Out:
#   name  score  strategy
# 2   ed     73  Scissors
